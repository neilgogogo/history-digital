# %% [markdown]
# # 分词部分

# %%
import os 
import re
import jieba
import json
import pandas as pd

# %%
### ONLY FOR TEST
def test_segmentation(poem, user_dict=None):   
    for s in poem:
        seg_list = jieba.cut(s, cut_all=False)  
        print('/'.join(list(seg_list)))
        
def run_test_1(user_dict=None):
    poem = ['秦川雄帝宅，函谷壯皇居。', '綺殿千尋起，離宮百雉餘。', '連甍遙接漢，飛觀迥凌虛。', '雲日隱層闕，風煙出綺疎。']
    print('Poem #1')
    test_segmentation(poem, user_dict)
    
    poem = ['遠山媚平楚，宿雨漲清溪。', '沿泝任舟檝，歡言無町畦。', '夜深忽梦少年事，梦啼妆泪红阑干']
    print('Poem #2')
    test_segmentation(poem, user_dict)
    
    poem = ['剑外忽传收蓟北，初闻涕泪满衣裳。',
            '却看妻子愁何在，漫卷诗书喜欲狂。',
            '白日放歌须纵酒，青春作伴好还乡。',
            '即从巴峡穿巫峡，便下襄阳向洛阳。']
    print('Poem #3')
    test_segmentation(poem, user_dict)
    
    poem = ['明月几时有，把酒问青天。', '不知天上宫阙，今夕是何年。', '我欲乘风归去，又恐琼楼玉宇，高处不胜寒。', '起舞弄清影，何似在人间。',
              '转朱阁，低绮户，照无眠。', '不应有恨，何事长向别时圆。', '人有悲欢离合，月有阴晴圆缺，此事古难全。', '但愿人长久，千里共婵娟。']
    print('Poem #4')
    test_segmentation(poem, user_dict)

# %%
LYRIC_DIR = './ci/'
POEM_DIR = './json/'

# %% [markdown]
# ## 唐诗

# %% [markdown]
# 先测试一下jieba分词的原始分词功能，以下诗句明显分错：
# + 秦川/雄帝/宅/
# + 沿/泝/任舟/檝/，/歡言/無/町/畦/
# + /月/有/阴晴圆/缺/

# %%
run_test_1()
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/p6/kb71f5k967ldvqs9b6zb82qw0000gn/T/jieba.cache
# Poem #1
# Loading model cost 0.706 seconds.
# Prefix dict has been built successfully.
# 秦川/雄帝/宅/，/函谷壯/皇居/。
# 綺/殿/千尋起/，/離宮/百雉/餘/。
# 連/甍/遙/接漢/，/飛觀/迥凌虛/。
# 雲日/隱層/闕/，/風煙出/綺/疎/。
# Poem #2
# 遠山媚/平楚/，/宿雨漲/清溪/。
# 沿/泝/任舟/檝/，/歡言/無/町/畦/。
# 夜深/忽梦/少年/事/，/梦啼妆泪/红/阑干
# Poem #3
# 剑外/忽/传收/蓟北/，/初闻/涕泪/满/衣裳/。
# 却/看/妻子/愁/何在/，/漫卷/诗书/喜欲狂/。
# 白日/放歌/须/纵酒/，/青春/作伴/好/还乡/。
# 即/从/巴峡/穿/巫峡/，/便/下/襄阳/向/洛阳/。
# Poem #4
# 明月/几时/有/，/把酒/问青天/。
# 不知/天上/宫阙/，/今夕/是/何年/。
# 我/欲/乘风/归去/，/又/恐/琼楼玉宇/，/高处不胜/寒/。
# 起舞/弄清/影/，/何似/在/人间/。
# 转朱阁/，/低绮户/，/照无眠/。
# 不/应有/恨/，/何事/长向/别时圆/。
# 人有/悲欢离合/，/月/有/阴晴圆/缺/，/此事/古难全/。
# 但愿人长久/，/千里/共/婵娟/。

# %% [markdown]
# 接下来我的想法是，先根据五字句的前两个字和七字句的前四个字构建词典，然后以此作为分词词典对整句进行分词。
#
# 我用了全唐诗和全宋诗作为数据集来构建词典。经测试，比只使用全唐诗更加精确。

# %%
poems = []
file_list = os.listdir(POEM_DIR)
for file in file_list:
    if file.startswith('poet.'):
        poems.append(pd.read_json(f'{POEM_DIR}{file}'))
poem_df = pd.concat(poems, ignore_index=True)

# %%
def cut_lines(poem):
    lines = []
    pattern = r',|\.|/|;|\'|`|\[|\]|<|>|\?|:|"|\{|\}|\~|!|@|#|\$|%|\^|&|\(|\)|-|=|\_|\+|，|。|、|；|‘|’|【|】|·|！| |…|（|）'
    for pairs in poem:
        lines.extend(list(filter(lambda x: len(x) > 0, re.split(pattern, pairs))))
    return lines

# %%
poem_df['lines'] = poem_df['paragraphs'].apply(cut_lines)

# %%
def first_segment(lines):
    words = []
    for line in lines:
        if len(line) == 5: 
            words.append(line[0:2])
        if len(line) == 7: 
            words.append(line[0:2])
            words.append(line[2:4])
    return words

# %%
poem_df['dic'] = poem_df['lines'].apply(first_segment)

# %%
word_freq = dict()

dictionary = [item for sublist in poem_df['dic'] for item in sublist]
for i in dictionary:
    word_freq[i] = word_freq.get(i, 0) + 1

word_freq = {key:val for key, val in word_freq.items() if val >= 3}

with open('./poem_dict.txt', 'w', encoding='utf-8') as f:
    for k, v in word_freq.items():
        f.write(f'{k} {v}\n')

jieba.set_dictionary('./poem_dict.txt')

# %% [markdown]
# 测试目前词典的分词效果。可见之前使用原始词典分错的地方都能分对，但是也添加了几处错误：
# + /梦啼妆泪/红/阑/干
# + /初闻涕/泪满/衣裳/
# + 我欲/乘风/归/去/
#
# 但是目前我们只关心唐诗的五字句和七字句的后三个字的分词，所以可以认为效果明显变好，毕竟“雄/帝宅”，“任/舟檝”，“無/町畦”等都能分对。

# %%
run_test_1()
# Out:
# Building prefix dict from /Users/lihangqian/Documents/08洛桑联邦理工/lectures/History and the digital/history-digital-main/poem_dict.txt ...
# Poem #1
# Dumping model to file cache /var/folders/p6/kb71f5k967ldvqs9b6zb82qw0000gn/T/jieba.u04e80a0a4359adea0c01661aca1641c1.cache
# Loading model cost 0.322 seconds.
# Prefix dict has been built successfully.
# 秦川/雄/帝宅/，/函谷/壯/皇居/。
# 綺/殿/千尋/起/，/離宮/百雉/餘/。
# 連甍/遙接漢/，/飛觀/迥/凌虛/。
# 雲日/隱層/闕/，/風煙/出/綺疎/。
# Poem #2
# 遠山/媚/平楚/，/宿雨/漲/清溪/。
# 沿泝/任/舟檝/，/歡言/無/町畦/。
# 夜深/忽梦/少年/事/，/梦啼妆泪/红/阑/干
# Poem #3
# 剑外/忽/传收/蓟北/，/初闻涕/泪满/衣裳/。
# 却看/妻子/愁/何在/，/漫卷/诗书/喜欲狂/。
# 白日/放歌/须/纵酒/，/青春/作伴/好/还/乡/。
# 即/从/巴峡/穿/巫峡/，/便下/襄阳/向/洛阳/。
# Poem #4
# 明月/几时/有/，/把酒/问/青天/。
# 不知/天上/宫阙/，/今夕/是何/年/。
# 我欲/乘风/归/去/，/又恐/琼楼/玉宇/，/高处/不胜寒/。
# 起舞/弄/清影/，/何似/在人/间/。
# 转朱阁/，/低绮户/，/照无眠/。
# 不应/有恨/，/何事/长向别/时/圆/。
# 人有/悲欢/离合/，/月有/阴晴/圆缺/，/此事/古难全/。
# 但愿/人长/久/，/千里/共婵娟/。

# %% [markdown]
# 之后根据词典对后三个字再次进行分词，并据此扩充词典：

# %%
def addition_segment(phrase):
    result = jieba.lcut(phrase, cut_all=False)     
    if len(result) != 2:
        return phrase
    if len(result[0]) == 2:
        return result[0]
    return result[1]

def second_segment(lines):
    words = []
    for line in lines:
        if len(line) == 5:
            words.append(line[0:2])
            words.append(addition_segment(line[2:]))
        if len(line) == 7:
            words.append(line[0:2])
            words.append(line[2:4])
            words.append(addition_segment(line[4:]))
    return words

# %%
poem_df['dic_total'] = poem_df['lines'].apply(second_segment)

# %%
word_freq = dict()
dictionary = [item for sublist in poem_df['dic_total'] for item in sublist]
for i in dictionary:
    word_freq[i] = word_freq.get(i, 0) + 1

word_freq = {key:val for key, val in word_freq.items() if val >= 3}

with open('./whole_poem_dict.txt', 'w', encoding='utf-8') as f:
    for k, v in word_freq.items():
        f.write(f'{k} {v}\n')

jieba.set_dictionary('./whole_poem_dict.txt')

# %% [markdown]
# 第二次的分词效果如下，可见效果再次变好，我觉得和上次的分词效果相当，虽然修正了“初闻/涕泪/满/衣裳”，但是“却看/妻子/愁何/在”又分错了。

# %%
run_test_1()
# Out:
# Building prefix dict from /Users/lihangqian/Documents/08洛桑联邦理工/lectures/History and the digital/history-digital-main/whole_poem_dict.txt ...
# Poem #1
# Dumping model to file cache /var/folders/p6/kb71f5k967ldvqs9b6zb82qw0000gn/T/jieba.u451ede831b0b3f802f1e06d231cf5503.cache
# Loading model cost 0.371 seconds.
# Prefix dict has been built successfully.
# 秦川/雄/帝宅/，/函谷/壯/皇居/。
# 綺/殿/千尋/起/，/離宮/百雉/餘/。
# 連甍/遙接漢/，/飛觀/迥/凌虛/。
# 雲日/隱層/闕/，/風煙/出/綺疎/。
# Poem #2
# 遠山/媚/平楚/，/宿雨/漲/清溪/。
# 沿泝/任/舟檝/，/歡言/無/町畦/。
# 夜深/忽梦/少年/事/，/梦啼妆泪/红/阑/干
# Poem #3
# 剑外/忽/传收/蓟北/，/初闻/涕泪/满/衣裳/。
# 却看/妻子/愁何/在/，/漫卷/诗书/喜欲狂/。
# 白日/放歌/须/纵酒/，/青春/作伴/好/还/乡/。
# 即/从/巴峡/穿/巫峡/，/便下/襄阳/向/洛阳/。
# Poem #4
# 明月/几时/有/，/把酒/问/青天/。
# 不知/天上/宫阙/，/今夕/是何/年/。
# 我欲/乘风/归/去/，/又恐/琼楼/玉宇/，/高处/不胜寒/。
# 起舞/弄/清影/，/何似/在人/间/。
# 转朱阁/，/低绮户/，/照无眠/。
# 不应/有恨/，/何事/长向别/时/圆/。
# 人有/悲欢/离合/，/月有/阴晴/圆缺/，/此事/古难全/。
# 但愿/人长/久/，/千里/共婵娟/。

# %% [markdown]
# 总结，jieba分词很有问题，词典中单词的频率并不能有效改善分词结果。比如在自定义的词典中，明明没有“愁何”，而且“何在”出现了很多次，但jieba仍然分成了“愁何/在”。
#
# jieba的这个问题已经讨论了好几年了：
# https://github.com/fxsjy/jieba/issues/14

# %% [markdown]
# ## 宋词

# %% [markdown]
# 我本想人工划分意向，但有些名句出现得太例外：
# + 六字句通常划分方式各异，最常见的为222式，但有的名句与众不同：七八个星天外，两三点雨山前。
# + “满江红”此句与别句的划分方式都不同：“驾长车，踏破贺兰山缺”，加之“贺兰山”是地名，故最好不要人工划分。
#
# 所以只能重回之前用的套路，先提取五字句中的前两个字和七字句中的前四字扩充词典，再根据扩充后的词典分词。

# %%
lyrics = []
file_list = os.listdir(LYRIC_DIR)
for file in file_list:
    if file.startswith('ci.song'):
        lyrics.append(pd.read_json(f'{LYRIC_DIR}{file}'))
lyric_df = pd.concat(lyrics, ignore_index=True)
lyric_df
# Out:
#       author                                         paragraphs rhythmic tags  \
# 0         张榘  [碧油推上客。, 有神机沈密，参运帷幄。, 威声际沙漠。, 庆云飞川泳，和熏三白。, 霄渊鬲...      瑞鹤仙  NaN
# 1         张榘  [绿野归来，筇杖角巾，岂不快哉。, 有清泉白石，东西岩岫，翠阴红影，高下楼台。, 况是蕤宾，...      沁园春  NaN
# 2         张榘  [豆花轻雨霁，更七日、是中秋。, 记分野三台，家山双阙，孕秀名流。, 平生佐时大略，有忠勤、...     木兰花慢  NaN
# 3         张榘  [素壁走龙蛇，难觅醉翁真迹。, 惟有断岗衰草，是几番经历。, 紫萸黄菊又西风，同作携壶客。,...      好事近  NaN
# 4         张榘  [望神京、目断烟草，青天长剑频倚。, 香街十里朱帘月，空想当年华丽。, 堪叹处。, 渺沙霭蒹...      摸鱼儿  NaN
# ...      ...                                                ...      ...  ...
# 21048     楼钥  [冷然。, 清圆。, 谁弹。, 向屋山。, 何言。, 清风至阴德之天。, 悠馀响婵娟。, 方...      醉翁操  NaN
# 21049     楼钥  [孝宗纯孝，前圣更何加。, 高蹈处重华。, 丹成仙去龙輴远，越岸暮山遐。, 波臣先为卷寒沙。...       导引  NaN
# 21050     楼钥  [吾皇尽孝，宗庙务崇尊。, 巨典备弥文。, 巍巍东向开基主，七世神孙。, 追思九闰整乾坤。,...       导引  NaN
# 21051    张良臣                         [昨日豆花篱下过，忽然迎面好风吹。, 独自立多时。]      失调名  NaN
# 21052    张良臣  [四壁空围恨玉，十香浅捻啼绡。, 殷云度雨井桐凋。, 雁雁无书又到。, 别後钗分燕股，病馀镜...      西江月  NaN
#
#       prologue
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 21048      NaN
# 21049      NaN
# 21050      NaN
# 21051      NaN
# 21052      NaN
#
# [21053 rows x 5 columns]

# %% [markdown]
# 词牌名概览。出现次数最多的15个词牌名占了宋词的三分之一：

# %%
rhythm_df = lyric_df.groupby(['rhythmic']).count()
rhythm_df.sort_values(by='paragraphs', ascending=False).head(15)
# Out:
#           author  paragraphs  tags  prologue
# rhythmic
# 浣溪沙          776         776    16         1
# 水调歌头         743         743    45         0
# 鹧鸪天          657         657    19         0
# 菩萨蛮          598         598     9         0
# 满江红          549         549    30         0
# 西江月          490         490     7         2
# 临江仙          482         482    13         0
# 念奴娇          432         432    28         0
# 减字木兰花        425         425     4         0
# 沁园春          423         423    28         0
# 蝶恋花          416         416    16         0
# 点绛唇          390         390     7         2
# 失调名          372         372     3         0
# 贺新郎          361         361    37         0
# 清平乐          356         356     8         0

# %%
lyric_df['lines'] = lyric_df['paragraphs'].apply(cut_lines)

# %%
lyric_df['dic'] = lyric_df['lines'].apply(first_segment)
lyric_df['dic']
# Out:
# 0                            [碧油, 有神, 威声, 庆云, 更谁, 看鹅]
# 1                [有清, 照眼, 葵榴, 翦香, 看看, 算支, 应有, 天边, 为苍]
# 2                        [豆花, 记分, 一念, 须知, 万灶, 智勇, 喜色]
# 3                            [素壁, 是几, 紫萸, 黄菊, 同作, 负晴]
# 4                [香街, 十里, 渺沙, 咿ン, 怅杨, 陈迹, 看玉, 笑骋, 麟阁]
#                              ...
# 21048    [清风, 至阴, 悠馀, 迥立, 八音, 相宣, 聊将, 听之, 弦索, 未有, 逸韵]
# 21049    [前圣, 高蹈, 丹成, 仙去, 越岸, 波臣, 先为, 来往, 九虞, 礼举, 万世]
# 21050        [宗庙, 巨典, 巍巍, 东向, 追思, 九闰, 环宇, 从今, 密迩, 千载]
# 21051                            [昨日, 豆花, 忽然, 迎面, 独自]
# 21052                                [殷云, 度雨, 蛮江, 豆蔻]
# Name: dic, Length: 21053, dtype: object

# %%
word_freq = dict()
dictionary = [item for sublist in poem_df['dic'] for item in sublist]
lyric_dictionary = [item for sublist in lyric_df['dic'] for item in sublist]
dictionary.extend(lyric_dictionary)
for i in dictionary:
    word_freq[i] = word_freq.get(i, 0) + 1

word_freq = {key:val for key, val in word_freq.items() if val >= 3}
    
with open('./lyric_dict.txt', 'w', encoding='utf-8') as f:
    for k, v in word_freq.items():
        f.write(f'{k} {v * 100}\n')

jieba.set_dictionary('./lyric_dict.txt')

# %%
def lyric_second_segment(lines):
    words = []
    for line in lines:
        if len(line) == 5:
            words.append(line[0:2])
            words.append(addition_segment(line[2:]))
        if len(line) == 7:
            words.append(line[0:2])
            words.append(line[2:4])
            words.append(addition_segment(line[4:]))
        else:
            tmp = jieba.lcut(line, cut_all=False)
            words.extend(list(filter(lambda x: len(x) >= 2, tmp)))
    return words

# %%
lyric_df['dic_total'] = lyric_df['lines'].apply(lyric_second_segment)
# Out:
# Building prefix dict from /Users/lihangqian/Documents/08洛桑联邦理工/lectures/History and the digital/history-digital-main/lyric_dict.txt ...
# Dumping model to file cache /var/folders/p6/kb71f5k967ldvqs9b6zb82qw0000gn/T/jieba.u1ac65e3ace2d1afb4d2a899ff1209d9e.cache
# Loading model cost 0.332 seconds.
# Prefix dict has been built successfully.

# %%
run_test_1()
# Out:
# Poem #1
# 秦川/雄/帝宅/，/函谷/壯/皇居/。
# 綺/殿/千尋/起/，/離宮/百雉/餘/。
# 連甍/遙接漢/，/飛觀/迥/凌虛/。
# 雲日/隱層/闕/，/風煙/出/綺疎/。
# Poem #2
# 遠山/媚/平楚/，/宿雨/漲/清溪/。
# 沿泝/任/舟檝/，/歡言/無/町畦/。
# 夜深/忽梦/少年/事/，/梦/啼妆/泪红/阑干
# Poem #3
# 剑外/忽/传收/蓟北/，/初闻/涕泪/满/衣裳/。
# 却看/妻子/愁/何在/，/漫卷/诗书/喜欲狂/。
# 白日/放歌/须/纵酒/，/青春/作伴/好/还/乡/。
# 即/从/巴峡/穿/巫峡/，/便下/襄阳/向/洛阳/。
# Poem #4
# 明月/几时/有/，/把酒/问/青天/。
# 不知/天上/宫阙/，/今夕/是何/年/。
# 我欲/乘风/归去/，/又恐/琼楼/玉宇/，/高处/不胜/寒/。
# 起舞/弄/清影/，/何似/在人/间/。
# 转/朱阁/，/低绮户/，/照/无眠/。
# 不应/有恨/，/何事/长向/别时/圆/。
# 人有/悲欢/离合/，/月有/阴晴/圆缺/，/此事/古难全/。
# 但愿/人长/久/，/千里/共/婵娟/。

# %% [markdown]
# 最后一次分词的结果。“却看/妻子/愁/何在”终于分对了，虽然“梦/啼妆/泪红/阑干”分错，但是我们只关心对后三个字的分词，所以无伤大雅。最关键的是，“转/朱阁”终于分出来了，“千里/共/婵娟”的“婵娟”也分出来了。但是上述几个分词词典都没正确地分出“但愿/人长/久”，我看字典里没有“长久”和“人长”，所以我认为是它随便分了。

# %% [markdown]
# 总结一下我的想法：
#
# 假设：五字句AABBB的前两个字AA，七字句AABBCCC的前四个字AA和BB，统一视为可以直接提取出来的“好意象”。当然这个规律也有例外，但是我只找到白居易的“家在虾蟆陵下住”这一个反例，我觉得只是因为白居易本来就专门写通俗化口语化的诗。后三个字的分法大相径庭，所以需要借助分词工具。
#
# 做法：
# 1. 先用唐诗和宋诗的“好意象”构建词典，然后用得到的词典对五字句AABBB的后三个字BBB，七字句AABBCCC的后三个字CCC分词。用对BBB和CCC的分词结果扩充词典。
# 2. 唐诗的分词完成。分词结果就是好意象+后三个字的分词。
# 3. 用宋词里的五字句的和七字句的“好意象”扩充词典，对宋词其他句式进行分词，
# 4. 宋词的分词完成。分词结果就是：
#         对于五字句和七字句：好意象+后三个字的分词；
#         对于其他句式：整句的分词结果

# %%
song_df = lyric_df

poems = []
file_list = os.listdir(POEM_DIR)
for file in file_list:
    if file.startswith('poet.tang'):
        poems.append(pd.read_json(f'{POEM_DIR}{file}'))
tang_df = pd.concat(poems, ignore_index=True)
tang_df['lines'] = tang_df['paragraphs'].apply(cut_lines)
jieba.set_dictionary('./poem_dict.txt')
tang_df['dic_total'] = tang_df['lines'].apply(second_segment)
jieba.set_dictionary('./lyric_dict.txt')
# Out:
# Building prefix dict from /Users/lihangqian/Documents/08洛桑联邦理工/lectures/History and the digital/history-digital-main/poem_dict.txt ...
# Loading model from cache /var/folders/p6/kb71f5k967ldvqs9b6zb82qw0000gn/T/jieba.u04e80a0a4359adea0c01661aca1641c1.cache
# Loading model cost 0.220 seconds.
# Prefix dict has been built successfully.

# %% [markdown]
# 总之，目前可以使用tang_df['dic_total']和song_df['dic_total']来看唐诗和宋词的分词结果：

# %%
tang_df
# Out:
#       author                                         paragraphs    title  \
# 0        陳嘉言  [公子申敬愛，攜朋翫物華。, 人是平陽客，地即石崇家。, 水文生舊浦，風色滿新花。, 日暮連...  晦日宴高氏林亭
# 1        陳嘉言  [高門引冠蓋，下客抱支離。, 綺席珍羞滿，文場翰藻摛。, 蓂華彫上月，柳色藹春池。, 日斜歸...     晦日重宴
# 2        陳嘉言  [今夜可憐春，河橋多麗人。, 寶馬金爲絡，香車玉作輪。, 連手窺潘掾，分頭看洛神。, 重城自...  上元夜效小庾體
# 3        周彥暉  [砌蓂收晦魄，津柳競年華。, 既狎忘筌友，方淹投轄車。, 綺筵迴舞雪，瓊醑泛流霞。, 雲低上...  晦日宴高氏林亭
# 4        周彥暉  [春華歸柳樹，俯景落蓂枝。, 置驛銅街右，開筵玉浦陲。, 林煙含障密，竹雨帶珠危。, 興闌巾...     晦日重宴
# ...      ...                                                ...      ...
# 57607     耿湋  [寥寂荒壘下，客舍雨微微。, 門見苔生滿，心慙吏到稀。, 籬花看未發，海燕欲先歸。, 無限堪...     盩厔客舍
# 57608     耿湋  [傳經韋相後，賜筆漢家郎。, 幽閣諸生會，寒宵幾刻長。, 座中燈泛酒，簷外月如霜。, 人事多...    宿韋員外宅
# 57609     耿湋  [沃州初望海，攜手盡時髦。, 小暑開鵬翼，新蓂長鷺濤。, 月如芳草遠，身比夕陽高。, 羊祜傷...     登沃州山
# 57610     耿湋  [暝色休羣動，秋齋遠客情。, 細風和雨氣，寒竹度簾聲。, 日覺蹉跎近，天敎嬾慢成。, 誰能謁...  宿岐山姜明府廳
# 57611     耿湋  [共來修禊事，內顧一悲翁。, 玉鬢風塵下，花林絲管中。, 故山離水石，舊侶失鵷鴻。, 不及遊...      上巳日
#
#                                          id tags  \
# 0      30a199ac-e508-46c2-b3ed-ecbcda4e4d81  NaN
# 1      d3098b52-2a7b-4e81-9afc-af4f6ed53817  NaN
# 2      fb0abe69-b0e5-40d9-a852-5bddc6c38abf  NaN
# 3      d756f172-bcc6-4835-9efa-e3adc7c7d939  NaN
# 4      bcb57f9c-5b88-42f7-8316-af64a2c96c8f  NaN
# ...                                     ...  ...
# 57607  96d8b98d-6b4a-4eb0-b915-988296f67cd3  NaN
# 57608  94209809-403f-4bb0-9fef-04b603bed685  NaN
# 57609  e9b8408c-490a-4ea1-a458-f3249bb7ddaf  NaN
# 57610  79ebb031-490c-44b2-b892-b779ace88f3a  NaN
# 57611  65d4f851-0627-49b5-b0b7-fdb4aefc4429  NaN
#
#                                                    lines  \
# 0      [公子申敬愛, 攜朋翫物華, 人是平陽客, 地即石崇家, 水文生舊浦, 風色滿新花, 日暮連...
# 1      [高門引冠蓋, 下客抱支離, 綺席珍羞滿, 文場翰藻摛, 蓂華彫上月, 柳色藹春池, 日斜歸...
# 2      [今夜可憐春, 河橋多麗人, 寶馬金爲絡, 香車玉作輪, 連手窺潘掾, 分頭看洛神, 重城自...
# 3      [砌蓂收晦魄, 津柳競年華, 既狎忘筌友, 方淹投轄車, 綺筵迴舞雪, 瓊醑泛流霞, 雲低上...
# 4      [春華歸柳樹, 俯景落蓂枝, 置驛銅街右, 開筵玉浦陲, 林煙含障密, 竹雨帶珠危, 興闌巾...
# ...                                                  ...
# 57607  [寥寂荒壘下, 客舍雨微微, 門見苔生滿, 心慙吏到稀, 籬花看未發, 海燕欲先歸, 無限堪...
# 57608  [傳經韋相後, 賜筆漢家郎, 幽閣諸生會, 寒宵幾刻長, 座中燈泛酒, 簷外月如霜, 人事多...
# 57609  [沃州初望海, 攜手盡時髦, 小暑開鵬翼, 新蓂長鷺濤, 月如芳草遠, 身比夕陽高, 羊祜傷...
# 57610  [暝色休羣動, 秋齋遠客情, 細風和雨氣, 寒竹度簾聲, 日覺蹉跎近, 天敎嬾慢成, 誰能謁...
# 57611  [共來修禊事, 內顧一悲翁, 玉鬢風塵下, 花林絲管中, 故山離水石, 舊侶失鵷鴻, 不及遊...
#
#                                                dic_total
# 0      [公子, 敬愛, 攜朋, 翫物, 人是, 平陽, 地即, 石崇, 水文, 舊浦, 風色, 新...
# 1      [高門, 冠蓋, 下客, 支離, 綺席, 珍羞, 文場, 翰藻, 蓂華, 上月, 柳色, 春...
# 2      [今夜, 可憐, 河橋, 麗人, 寶馬, 金爲, 香車, 玉作, 連手, 窺潘掾, 分頭, ...
# 3      [砌蓂, 收晦, 津柳, 年華, 既狎, 忘筌, 方淹, 投轄, 綺筵, 舞雪, 瓊醑, 流...
# 4      [春華, 柳樹, 俯景, 落蓂枝, 置驛, 銅街, 開筵, 玉浦陲, 林煙, 含障, 竹雨,...
# ...                                                  ...
# 57607  [寥寂, 荒壘, 客舍, 雨微, 門見, 苔生, 心慙, 吏到, 籬花, 未發, 海燕, 欲...
# 57608  [傳經, 韋相, 賜筆, 漢家, 幽閣, 諸生, 寒宵, 幾刻, 座中, 泛酒, 簷外, 月...
# 57609  [沃州, 望海, 攜手, 盡時, 小暑, 鵬翼, 新蓂, 鷺濤, 月如, 芳草, 身比, 夕...
# 57610  [暝色, 羣動, 秋齋, 遠客, 細風, 和雨, 寒竹, 度簾聲, 日覺, 蹉跎, 天敎, ...
# 57611  [共來, 修禊, 內顧, 一悲, 玉鬢, 風塵, 花林, 絲管, 故山, 水石, 舊侶, 鵷...
#
# [57612 rows x 7 columns]

# %%
song_df
# Out:
#       author                                         paragraphs rhythmic tags  \
# 0         张榘  [碧油推上客。, 有神机沈密，参运帷幄。, 威声际沙漠。, 庆云飞川泳，和熏三白。, 霄渊鬲...      瑞鹤仙  NaN
# 1         张榘  [绿野归来，筇杖角巾，岂不快哉。, 有清泉白石，东西岩岫，翠阴红影，高下楼台。, 况是蕤宾，...      沁园春  NaN
# 2         张榘  [豆花轻雨霁，更七日、是中秋。, 记分野三台，家山双阙，孕秀名流。, 平生佐时大略，有忠勤、...     木兰花慢  NaN
# 3         张榘  [素壁走龙蛇，难觅醉翁真迹。, 惟有断岗衰草，是几番经历。, 紫萸黄菊又西风，同作携壶客。,...      好事近  NaN
# 4         张榘  [望神京、目断烟草，青天长剑频倚。, 香街十里朱帘月，空想当年华丽。, 堪叹处。, 渺沙霭蒹...      摸鱼儿  NaN
# ...      ...                                                ...      ...  ...
# 21048     楼钥  [冷然。, 清圆。, 谁弹。, 向屋山。, 何言。, 清风至阴德之天。, 悠馀响婵娟。, 方...      醉翁操  NaN
# 21049     楼钥  [孝宗纯孝，前圣更何加。, 高蹈处重华。, 丹成仙去龙輴远，越岸暮山遐。, 波臣先为卷寒沙。...       导引  NaN
# 21050     楼钥  [吾皇尽孝，宗庙务崇尊。, 巨典备弥文。, 巍巍东向开基主，七世神孙。, 追思九闰整乾坤。,...       导引  NaN
# 21051    张良臣                         [昨日豆花篱下过，忽然迎面好风吹。, 独自立多时。]      失调名  NaN
# 21052    张良臣  [四壁空围恨玉，十香浅捻啼绡。, 殷云度雨井桐凋。, 雁雁无书又到。, 别後钗分燕股，病馀镜...      西江月  NaN
#
#       prologue                                              lines  \
# 0          NaN  [碧油推上客, 有神机沈密, 参运帷幄, 威声际沙漠, 庆云飞川泳, 和熏三白, 霄渊鬲, ...
# 1          NaN  [绿野归来, 筇杖角巾, 岂不快哉, 有清泉白石, 东西岩岫, 翠阴红影, 高下楼台, 况是...
# 2          NaN  [豆花轻雨霁, 更七日, 是中秋, 记分野三台, 家山双阙, 孕秀名流, 平生佐时大略, 有...
# 3          NaN  [素壁走龙蛇, 难觅醉翁真迹, 惟有断岗衰草, 是几番经历, 紫萸黄菊又西风, 同作携壶客,...
# 4          NaN  [望神京, 目断烟草, 青天长剑频倚, 香街十里朱帘月, 空想当年华丽, 堪叹处, 渺沙霭蒹...
# ...        ...                                                ...
# 21048      NaN  [冷然, 清圆, 谁弹, 向屋山, 何言, 清风至阴德之天, 悠馀响婵娟, 方昼眠, 迥立八...
# 21049      NaN  [孝宗纯孝, 前圣更何加, 高蹈处重华, 丹成仙去龙輴远, 越岸暮山遐, 波臣先为卷寒沙, ...
# 21050      NaN  [吾皇尽孝, 宗庙务崇尊, 巨典备弥文, 巍巍东向开基主, 七世神孙, 追思九闰整乾坤, 环...
# 21051      NaN                          [昨日豆花篱下过, 忽然迎面好风吹, 独自立多时]
# 21052      NaN  [四壁空围恨玉, 十香浅捻啼绡, 殷云度雨井桐凋, 雁雁无书又到, 别後钗分燕股, 病馀镜减...
#
#                                                 dic  \
# 0                          [碧油, 有神, 威声, 庆云, 更谁, 看鹅]
# 1              [有清, 照眼, 葵榴, 翦香, 看看, 算支, 应有, 天边, 为苍]
# 2                      [豆花, 记分, 一念, 须知, 万灶, 智勇, 喜色]
# 3                          [素壁, 是几, 紫萸, 黄菊, 同作, 负晴]
# 4              [香街, 十里, 渺沙, 咿ン, 怅杨, 陈迹, 看玉, 笑骋, 麟阁]
# ...                                             ...
# 21048  [清风, 至阴, 悠馀, 迥立, 八音, 相宣, 聊将, 听之, 弦索, 未有, 逸韵]
# 21049  [前圣, 高蹈, 丹成, 仙去, 越岸, 波臣, 先为, 来往, 九虞, 礼举, 万世]
# 21050      [宗庙, 巨典, 巍巍, 东向, 追思, 九闰, 环宇, 从今, 密迩, 千载]
# 21051                          [昨日, 豆花, 忽然, 迎面, 独自]
# 21052                              [殷云, 度雨, 蛮江, 豆蔻]
#
#                                                dic_total
# 0      [碧油, 推上, 碧油, 推上, 有神, 机沈密, 有神, 机沈密, 参运, 帷幄, 威声,...
# 1      [绿野, 归来, 筇杖, 角巾, 不快, 有清, 白石, 有清, 白石, 东西, 翠阴, 红...
# 2      [豆花, 雨霁, 豆花, 雨霁, 七日, 是中, 记分, 三台, 分野, 三台, 家山, 双...
# 3      [素壁, 走龙蛇, 素壁, 走龙蛇, 难觅, 醉翁, 真迹, 惟有, 断岗, 衰草, 是几,...
# 4      [神京, 目断, 烟草, 青天, 长剑, 频倚, 香街, 十里, 朱帘, 空想, 当年, 华...
# ...                                                  ...
# 21048  [冷然, 清圆, 屋山, 何言, 清风, 至阴, 德之, 悠馀, 婵娟, 悠馀响, 婵娟, ...
# 21049  [孝宗纯, 前圣, 更何, 前圣, 更何, 高蹈, 重华, 高蹈, 重华, 丹成, 仙去, ...
# 21050  [吾皇, 尽孝, 宗庙, 务崇尊, 宗庙务崇尊, 巨典, 备弥文, 巨典, 备弥文, 巍巍,...
# 21051           [昨日, 豆花, 篱下, 忽然, 迎面, 好风, 独自, 多时, 独自, 多时]
# 21052  [四壁, 空围, 恨玉, 香浅, 殷云, 度雨, 井桐, 雁雁, 无书, 又到, 别後, 钗...
#
# [21053 rows x 8 columns]

# %%
tang_df.to_csv("tang_seg.csv")

# %%
song_df.to_csv("song_seg.csv")

# %%
libai = tang_df[tang_df['author']== '李白']
li_seg = libai['dic_total'].tolist()

# %%
li_seg[0]
# Out:
# ['三十',
#  '離宮',
#  '樓臺',
#  '與天',
#  '閣道',
#  '步行',
#  '美人',
#  '愁煙',
#  '恩疎',
#  '不及',
#  '桃李',
#  '傷春',
#  '淫樂',
#  '意何極',
#  '金輿',
#  '回中',
#  '萬乘',
#  '黃道',
#  '千旗',
#  '彩虹',
#  '前軍',
#  '細柳',
#  '後騎',
#  '甘泉',
#  '豈問',
#  '渭川',
#  '寧邀',
#  '野童',
#  '秋暮',
#  '瑤池',
#  '歸來',
#  '未窮']

# %%
import operator
from functools import reduce

li_list = reduce(operator.add, li_seg)
li_list
# Out:
# ['三十',
#  '離宮',
#  '樓臺',
#  '與天',
#  '閣道',
#  '步行',
#  '美人',
#  '愁煙',
#  '恩疎',
#  '不及',
#  '桃李',
#  '傷春',
#  '淫樂',
#  '意何極',
#  '金輿',
#  '回中',
#  '萬乘',
#  '黃道',
#  '千旗',
#  '彩虹',
#  '前軍',
#  '細柳',
#  '後騎',
#  '甘泉',
#  '豈問',
#  '渭川',
#  '寧邀',
#  '野童',
#  '秋暮',
#  '瑤池',
#  '歸來',
#  '未窮',
#  '洗兵',
#  '條支',
#  '海上',
#  '放馬',
#  '天山',
#  '雪中',
#  '萬里',
#  '長征',
#  '三軍',
#  '衰老',
#  '秦家',
#  '築城',
#  '備胡處',
#  '漢家',
#  '還有',
#  '烽火',
#  '烽火',
#  '不息',
#  '征戰',
#  '無已',
#  '野戰',
#  '格鬬',
#  '敗馬',
#  '號鳴',
#  '向天',
#  '烏鳶',
#  '人腸',
#  '銜飛',
#  '上挂',
#  '枯樹',
#  '士卒',
#  '草莽',
#  '將軍',
#  '空爾',
#  '乃知',
#  '兵者',
#  '凶器',
#  '奔流',
#  '到海',
#  '不復',
#  '朝如',
#  '青絲',
#  '成雪',
#  '人生',
#  '得意',
#  '須盡',
#  '莫使',
#  '金尊',
#  '空對',
#  '天生',
#  '我材',
#  '必有',
#  '千金',
#  '散盡',
#  '還復',
#  '烹羊',
#  '宰牛',
#  '且爲',
#  '會須',
#  '一飲',
#  '三百',
#  '與君',
#  '一曲',
#  '請君',
#  '爲我',
#  '側耳',
#  '鐘鼓',
#  '饌玉',
#  '不足',
#  '但願',
#  '長醉',
#  '不復',
#  '古來',
#  '聖賢',
#  '寂寞',
#  '惟有',
#  '飲者',
#  '其名',
#  '陳王',
#  '昔時',
#  '平樂',
#  '斗酒',
#  '十千',
#  '恣歡',
#  '主人',
#  '何爲',
#  '言少',
#  '徑須',
#  '酤取',
#  '對君',
#  '呼兒',
#  '將出',
#  '美酒',
#  '與爾',
#  '同銷',
#  '萬古',
#  '馬色',
#  '雖不',
#  '人心',
#  '本無',
#  '共作',
#  '遊冶',
#  '雙行',
#  '洛陽',
#  '長劒',
#  '照曜',
#  '高冠',
#  '何赩赫',
#  '各有',
#  '千金',
#  '俱爲',
#  '五侯',
#  '猛虎',
#  '陷穽',
#  '壯夫',
#  '時屈',
#  '相知',
#  '急難',
#  '獨好',
#  '亦何',
#  '乃在',
#  '碧海',
#  '之東',
#  '海寒',
#  '天風',
#  '白波',
#  '連山',
#  '蓬壺',
#  '長鯨',
#  '噴湧',
#  '不可',
#  '撫心',
#  '茫茫',
#  '淚如',
#  '西來',
#  '青鳥',
#  '東飛',
#  '願寄',
#  '一書',
#  '麻姑',
#  '辟邪',
#  '伎作',
#  '鼓吹',
#  '雉子',
#  '班之',
#  '奏曲',
#  '喔咿',
#  '振迅',
#  '欲飛',
#  '雙雌',
#  '同飲',
#  '趫悍',
#  '誰能',
#  '乍向',
#  '草中',
#  '耿介',
#  '不求',
#  '黃金',
#  '下生',
#  '天地',
#  '廣大',
#  '何惜',
#  '物情',
#  '善卷',
#  '天子',
#  '務光',
#  '逃名',
#  '所貴',
#  '曠士',
#  '朗然',
#  '太清',
#  '垂楊',
#  '綠水',
#  '搖豔',
#  '東風',
#  '花明',
#  '玉關',
#  '葉暖',
#  '金窗',
#  '美人',
#  '長恨',
#  '相對',
#  '悽然',
#  '攀條',
#  '春色',
#  '遠寄',
#  '龍庭',
#  '明月',
#  '天山',
#  '蒼茫',
#  '雲海',
#  '長風',
#  '幾萬',
#  '吹度',
#  '玉門',
#  '漢下',
#  '白登',
#  '胡窺',
#  '青海',
#  '由來',
#  '征戰',
#  '不見',
#  '有人',
#  '戍客',
#  '邊色',
#  '思歸',
#  '多苦顏',
#  '高樓',
#  '當此',
#  '歎息',
#  '未應',
#  '彼美',
#  '漢東',
#  '川藏',
#  '明月',
#  '寧知',
#  '喪亂',
#  '更有',
#  '一珠',
#  '曉峰',
#  '如畫',
#  '參差',
#  '碑作',
#  '「參',
#  '差碧',
#  '藤影',
#  '風搖',
#  '拂檻',
#  '野徑',
#  '來多',
#  '將犬伴',
#  '人間',
#  '歸晚',
#  '碑作',
#  '「待」',
#  '看雲',
#  '客倚',
#  '啼猿',
#  '一作',
#  '「鷺」',
#  '或作',
#  '「鶩」',
#  '莫怪',
#  '無心',
#  '清境',
#  '已將',
#  '書劍',
#  '明時',
#  '厄磴',
#  '層層',
#  '太華',
#  '白雲',
#  '深處',
#  '有人',
#  '道童',
#  '對月',
#  '吹笛',
#  '仙子',
#  '乘雲',
#  '遠駕',
#  '恠石',
#  '堆山',
#  '如坐',
#  '老藤',
#  '纏樹',
#  '似騰',
#  '曾聞',
#  '玉井',
#  '金河',
#  '會見',
#  '蓬萊',
#  '十丈',
#  '佽飛',
#  '長蛟',
#  '遺圖',
#  '畫中',
#  '登舟',
#  '虎嘯',
#  '激水',
#  '龍戰',
#  '驚波',
#  '連山',
#  '拔劍',
#  '雷電',
#  '鱗摧',
#  '白刃',
#  '血染',
#  '滄江',
#  '感此',
#  '古人',
#  '一作',
#  '「載」',
#  '本心',
#  '虛空',
#  '清淨',
#  '無一',
#  '焚蕩',
#  '淫怒',
#  '圓寂',
#  '了見',
#  '五綵',
#  '聖像',
#  '悟真',
#  '非妄',
#  '掃雪',
#  '萬病',
#  '爽然',
#  '清凉',
#  '讚此',
#  '功德',
#  '永爲',
#  '曠代',
#  '合沓',
#  '數峰',
#  '奔地',
#  '平楚',
#  '中間',
#  '最高',
#  '髣髴',
#  '接天',
#  '遙望',
#  '九華',
#  '誠然',
#  '九華',
#  '蒼顏',
#  '風雪',
#  '奇態',
#  '雲霞',
#  '曜日',
#  '凝成',
#  '凌霄',
#  '增壁',
#  '何當',
#  '餘蔭',
#  '天造',
#  '洞仙',
#  '聞說',
#  '神仙',
#  '葛洪',
#  '煉丹',
#  '曾此',
#  '占雲',
#  '庭前',
#  '廢井',
#  '今猶',
#  '不見',
#  '長松',
#  '短松',
#  '頭陀',
#  '萬仞',
#  '遠眺',
#  '華峰',
#  '聊借',
#  '金沙',
#  '洗開',
#  '九芙',
#  '煙嵐',
#  '遍覽',
#  '踏屐',
#  '雙龍',
#  '明日',
#  '登高',
#  '枕月',
#  '青松',
#  '更盡',
#  '聞呼',
#  '恍來',
#  '報曉',
#  '無相',
#  '寺建',
#  '唐初',
#  '道光',
#  '重修',
#  '聖寺',
#  '閑棲',
#  '睡眼',
#  '玉磬',
#  '時聞',
#  '一兩',
#  '朝披',
#  '夢澤',
#  '笠釣',
#  '茫茫',
#  '甲作',
#  '「流」',
#  '乙作',
#  '「綠」',
#  '乙作',
#  '「二」',
#  '篆字',
#  '若丹蛇',
#  '乙作',
#  '「遶」',
#  '歸來',
#  '問天',
#  '戊作',
#  '「姥」',
#  '戊作',
#  '「妙」',
#  '甲作',
#  '「刃」',
#  '甲作',
#  '「紫」',
#  '靈文',
#  '煌煌',
#  '戊作',
#  '「燕」',
#  '戊作',
#  '「鐶」',
#  '戊作',
#  '「想」',
#  '丙作',
#  '「騎」',
#  '丙作',
#  '「麟」',
#  '海氣',
#  '侵肌',
#  '戊作',
#  '「喜」',
#  '化作',
#  '梅花',
#  '戊作',
#  '「遺」',
#  '甲作',
#  '「非」',
#  '乙作',
#  '「絡」',
#  '戊作',
#  '「樓」',
#  '丁作',
#  '「裾」',
#  '甲作',
#  '「當」',
#  '戊作',
#  '「璫」',
#  '戊作',
#  '「揖」',
#  '甲作',
#  '「予」',
#  '甲作',
#  '「疾」',
#  '乙作',
#  '「詞」',
#  '戊作',
#  '「辭」',
#  '戊作',
#  '「餘」',
#  '「光',
#  '三韻',
#  '「涼',
#  '二韻',
#  '人生',
#  '燭上',
#  '乙作',
#  '「火」',
#  '春風',
#  '繞樹',
#  '戊作',
#  '「花」',
#  '戊作',
#  '「惟」',
#  '戊作',
#  '「念」',
#  '慘見',
#  '當塗',
#  '戊作',
#  '「明」',
#  '戊作',
#  '「上」',
#  '既死',
#  '明月',
#  '戊作',
#  '「彼」',
#  '戊作',
#  '「瓈」',
#  '念此',
#  '一脫',
#  '戊作',
#  '「酒」',
#  '戊作',
#  '「登」',
#  '戊作',
#  '「鳳」',
#  '星斗',
#  '可捫',
#  '有道',
#  '相訪',
#  '口誦',
#  '此二',
#  '笠釣',
#  '茫茫',
#  '』此',
#  '非世',
#  '人語',
#  '有道',
#  '相訪',
#  '東坡',
#  '定武',
#  '王仲',
#  '弓別',
#  '惠濟',
#  '又出',
#  '此二',
#  '曰此',
#  '李真',
#  '人作',
#  '墨跡',
#  '如未',
#  '笠釣',
#  '茫茫',
#  '慘見',
#  '當塗',
#  '今莫',
#  '孰是',
#  '眼前',
#  '有景',
#  '道不',
#  '崔顥',
#  '題詩',
#  '在上',
#  '妙有',
#  '二氣',
#  '靈山',
#  '九華',
#  '層標',
#  '遲日',
#  '半壁',
#  '明朝',
#  '積雪',
#  '陰壑',
#  '飛流',
#  '陽崖',
#  '青瑩',
#  '玉樹',
#  '縹緲',
#  '羽人',
#  '昔君',
#  '布衣',
#  '與妾',
#  '辛苦',
#  '一拜',
#  '五官',
#  '便索',
#  '邯鄲',
#  '妾欲',
#  '辭君',
#  '君心',
#  '相許',
#  '妾讀',
#  '蘼蕪',
#  '悲歌',
#  '淚如',
#  '憶昔',
#  '君時',
#  '曾無',
#  '一夜',
#  '不是',
#  '妾無',
#  '君家',
#  '難作',
#  '起來',
#  '強歌',
#  '縱好',
#  '君嫌',
#  '下堂',
#  '辭君',
#  '去後',
#  '遮莫',
#  '秦樓',
#  '佳麗',
#  '正值',
#  '朝日',
#  '陌頭',
#  '能駐',
#  '花處',
#  '添香',
#  '等閑',
#  '經夏',
#  '經寒',
#  '夢裏',
#  '驚嗟',
#  '暫安',
#  '南家',
#  '風光',
#  '當世',
#  '西陵',
#  '江浪',
#  '過江',
#  '周旋',
#  '小字',
#  '桃燈',
#  '重疊',
#  '遙山',
#  '隔霧',
#  '真是',
#  '爲君',
#  '不得',
#  '書來',
#  '莫說',
#  '更加',
#  '嚴羽',
#  '《滄',
#  '詩話',
#  '「彥',
#  '」形',
#  '近易',
#  '芣苡',
#  '生前',
#  '含桃',
#  '小園',
#  '春心',
#  '搖蕩',
#  '百舌',
#  '更多',
#  '從戎',
#  '邊北',
#  '遠行',
#  '辭密親',
#  '借問',
#  '陰山',
#  '還知',
#  '塞上',
#  '但緊',
#  '接李',
#  '詩後',
#  '於例',
#  '並非',
#  '李白',
#  '磨盡',
#  '石嶺',
#  '潯陽',
#  '赤魚',
#  '靄峯',
#  '似筆',
#  '堪畫',
#  '不堪',
#  '相傳',
#  '太白',
#  '新安',
#  '《九',
#  '域志',
#  '《錦',
#  '繡萬',
#  '花谷',
#  '以爲',
#  '太白',
#  '「筆',
#  '」作',
#  '「削」',
#  '黟縣',
#  '小桃',
#  '烟霞',
#  '百里',
#  '地多',
#  '靈草',
#  '人尚',
#  '衣冠',
#  '市向',
#  '晡前散',
#  '山經',
#  '夜後',
#  '以爲',
#  '太白',
#  '皆未',
#  '收此',
#  '今仍',
#  '存之',
#  '夜宿',
#  '烏牙寺',
#  '舉手',
#  '捫星',
#  '不取',
#  '高聲',
#  '恐驚',
#  '天上',
#  '曰李',
#  '太白',
#  '李集',
#  '中無',
#  '」又',
#  '《侯',
#  '鯖錄',
#  '王琦',
#  '亦未',
#  '能定',
#  '昔日',
#  '狂秦',
#  '事可',
#  '直驅',
#  '雞犬',
#  '桃花',
#  '一作',
#  '「巒」',
#  '萬古',
#  '潺湲',
#  '一作',
#  '「一」',
#  '露暗',
#  '煙濃',
#  '草色',
#  '一翻',
#  '流水',
#  '滿溪',
#  '只見',
#  '桃花',
#  '不見',
#  '天台',
#  '國清',
#  '天下',
#  '四絕',
#  '今到',
#  '普照',
#  '到來',
#  '復何',
#  '一作',
#  '「枿」',
#  '高僧',
#  '殘雪',
#  '一作',
#  '「前」',
#  '一作',
#  '「水」',
#  '幾回',
#  '歲月',
#  '見國',
#  '清院',
#  '太白',
#  '幾回',
#  '碎月',
#  '即此',
#  '篇末',
#  '二句',
#  '蓋未',
#  '全篇',
#  '天台',
#  '國清',
#  '天下',
#  '四絕',
#  '我來',
#  '舉唐遊',
#  '於中',
#  '更無',
#  '枿木',
#  '劃斷',
#  '高峯',
#  '積雪',
#  '檻外',
#  '一條',
#  '幾回',
#  '碎月',
#  '殷侯',
#  '三玄',
#  '贈我',
#  '栗岡硯',
#  '灑染',
#  '中山',
#  '光映',
#  '吳門',
#  '天寒',
#  '水不',
#  '日用',
#  '心不',
#  '攜此',
#  '墨池',
#  '還如',
#  '對君',
#  '嵐光',
#  '深院',
#  '傍砌',
#  '泠泠',
#  '野燕',
#  '官舍',
#  '日斜',
#  '孤吏過',
#  '簾捲',
#  '亂峯',
#  '五色',
#  '神仙',
#  '焚香',
#  '道經',
#  '刻在',
#  '縣衛',
#  '六即',
#  '潁水',
#  '何慚',
#  '許郡賓',
#  '相逢',
#  '太史',
#  '應是',
#  '賢人',
#  '玉隱',
#  '且在',
#  '蘭枯',
#  '還見',
#  '俄成',
#  '萬里',
#  '立德',
#  '清真',
#  '熱暖',
#  '將來',
#  '賓鐵文',
#  '暫時',
#  '不動',
#  '白雲',
#  '撥卻',
#  '白雲',
#  '青天',
#  '掇頭',
#  '裏許',
#  '便乘',
#  '知見',
#  '一何',
#  '拭眼',
#  '天位',
#  '同觀',
#  '洗耳',
#  '千古',
#  '應無',
#  '石笋',
#  '卓筆',
#  '縣之',
#  '山之',
#  '誰爲',
#  '不平',
#  '與之',
#  '青天',
#  '朝披',
#  '夢澤',
#  '笠釣',
#  '茫茫',
#  '暮跨',
#  '紫鱗',
#  '海氣',
#  '侵肌',
#  '墨跡',
#  '如未',
#  '庭中',
#  '繁樹',
#  '含芳',
#  '紅錦',
#  '重重',
#  '翦作',
#  '還合',
#  '炎蒸',
#  '留爍景',
#  '題來',
#  '渭得',
#  '篇章',
#  '樵夫',
#  '耕者',
#  '出入',
#  '畫屏',
#  '野禽',
#  '杜宇',
#  '山蝶',
#  '莊周',
#  '霜結',
#  '梅梢',
#  '陰凝',
#  '竹幹',
#  '竹粉',
#  '千腰',
#  '桃皮',
#  '頰紅',
#  '心爲',
#  '殺人',
#  '淚是',
#  '報恩',
#  '佳人',
#  '微醉',
#  '玉顏',
#  '笑伾',
#  '粧樓',
#  '澹小蛾',
#  '借問',
#  '單樓',
#  '同穴',
#  '可能',
#  '銀漢',
#  '重泉',
#  '舉頭',
#  '忽見',
#  '衡陽',
#  '千聲',
#  '萬字',
#  '何限',
#  '叵耐',
#  '薄情',
#  '一行',
#  '也無',
#  '泣歸',
#  '香閣',
#  '和淚',
#  '紅粉',
#  '待雁',
#  '却回',
#  '也無',
#  '書寄',
#  '《尊',
#  '前集',
#  '大雅',
#  '久不',
#  '吾衰',
#  '竟誰',
#  '王風',
#  '蔓草',
#  '戰國',
#  '荆榛',
#  '龍虎',
#  '相啖食',
#  '兵戈',
#  '逮狂',
#  '正聲',
#  '微茫',
#  '哀怨',
#  '騷人',
#  '揚馬',
#  '頹波',
#  '開流',
#  '無垠',
#  '廢興',
#  '萬變',
#  '憲章',
#  '亦已',
#  '自從',
#  '建安',
#  '綺麗',
#  '不足',
#  '聖代',
#  '復元古',
#  '垂衣',
#  '清真',
#  '羣才',
#  '休明',
#  '乘運',
#  '共躍鱗',
#  '文質',
#  '炳煥',
#  '衆星',
#  '秋旻',
#  '我志',
#  '刪述',
#  '垂輝',
#  '千春',
#  '希聖',
#  '如有',
#  '絕筆',
#  '獲麟',
#  '蟾蜍',
#  '太清',
#  '蝕此',
#  '瑤臺',
#  '圓光',
#  '中天',
#  '金魄',
#  '淪沒',
#  '螮蝀',
#  '紫微',
#  '大明',
#  '朝暉',
#  '浮雲',
#  '兩曜',
#  '萬象',
#  '昏陰',
#  '蕭蕭',
#  '長門',
#  '昔是',
#  '今已',
#  ...]

# %%
from collections import Counter

result_li = Counter(li_list)

# %%
result_li
# Out:
# Counter({'三十': 19,
#          '離宮': 3,
#          '樓臺': 5,
#          '與天': 9,
#          '閣道': 3,
#          '步行': 2,
#          '美人': 28,
#          '愁煙': 1,
#          '恩疎': 4,
#          '不及': 13,
#          '桃李': 42,
#          '傷春': 2,
#          '淫樂': 3,
#          '意何極': 2,
#          '金輿': 3,
#          '回中': 3,
#          '萬乘': 16,
#          '黃道': 2,
#          '千旗': 2,
#          '彩虹': 5,
#          '前軍': 2,
#          '細柳': 4,
#          '後騎': 2,
#          '甘泉': 5,
#          '豈問': 2,
#          '渭川': 4,
#          '寧邀': 2,
#          '野童': 2,
#          '秋暮': 1,
#          '瑤池': 7,
#          '歸來': 26,
#          '未窮': 5,
#          '洗兵': 2,
#          '條支': 2,
#          '海上': 21,
#          '放馬': 2,
#          '天山': 8,
#          '雪中': 4,
#          '萬里': 60,
#          '長征': 2,
#          '三軍': 11,
#          '衰老': 5,
#          '秦家': 5,
#          '築城': 2,
#          '備胡處': 1,
#          '漢家': 13,
#          '還有': 4,
#          '烽火': 10,
#          '不息': 4,
#          '征戰': 8,
#          '無已': 2,
#          '野戰': 2,
#          '格鬬': 2,
#          '敗馬': 2,
#          '號鳴': 2,
#          '向天': 9,
#          '烏鳶': 4,
#          '人腸': 4,
#          '銜飛': 2,
#          '上挂': 2,
#          '枯樹': 2,
#          '士卒': 2,
#          '草莽': 2,
#          '將軍': 14,
#          '空爾': 3,
#          '乃知': 6,
#          '兵者': 2,
#          '凶器': 2,
#          '奔流': 2,
#          '到海': 2,
#          '不復': 10,
#          '朝如': 2,
#          '青絲': 7,
#          '成雪': 2,
#          '人生': 15,
#          '得意': 6,
#          '須盡': 2,
#          '莫使': 5,
#          '金尊': 4,
#          '空對': 2,
#          '天生': 3,
#          '我材': 2,
#          '必有': 2,
#          '千金': 20,
#          '散盡': 5,
#          '還復': 3,
#          '烹羊': 2,
#          '宰牛': 2,
#          '且爲': 6,
#          '會須': 2,
#          '一飲': 2,
#          '三百': 14,
#          '與君': 28,
#          '一曲': 5,
#          '請君': 4,
#          '爲我': 16,
#          '側耳': 2,
#          '鐘鼓': 3,
#          '饌玉': 2,
#          '不足': 17,
#          '但願': 4,
#          '長醉': 3,
#          '古來': 13,
#          '聖賢': 3,
#          '寂寞': 8,
#          '惟有': 10,
#          '飲者': 2,
#          '其名': 3,
#          '陳王': 3,
#          '昔時': 5,
#          '平樂': 2,
#          '斗酒': 10,
#          '十千': 6,
#          '恣歡': 1,
#          '主人': 17,
#          '何爲': 5,
#          '言少': 2,
#          '徑須': 3,
#          '酤取': 1,
#          '對君': 5,
#          '呼兒': 6,
#          '將出': 2,
#          '美酒': 27,
#          '與爾': 10,
#          '同銷': 2,
#          '萬古': 30,
#          '馬色': 2,
#          '雖不': 5,
#          '人心': 6,
#          '本無': 10,
#          '共作': 2,
#          '遊冶': 4,
#          '雙行': 4,
#          '洛陽': 27,
#          '長劒': 11,
#          '照曜': 2,
#          '高冠': 3,
#          '何赩赫': 2,
#          '各有': 4,
#          '俱爲': 3,
#          '五侯': 4,
#          '猛虎': 18,
#          '陷穽': 2,
#          '壯夫': 5,
#          '時屈': 2,
#          '相知': 7,
#          '急難': 3,
#          '獨好': 2,
#          '亦何': 10,
#          '乃在': 4,
#          '碧海': 6,
#          '之東': 2,
#          '海寒': 2,
#          '天風': 8,
#          '白波': 7,
#          '連山': 10,
#          '蓬壺': 9,
#          '長鯨': 12,
#          '噴湧': 2,
#          '不可': 75,
#          '撫心': 2,
#          '茫茫': 22,
#          '淚如': 14,
#          '西來': 14,
#          '青鳥': 6,
#          '東飛': 4,
#          '願寄': 2,
#          '一書': 6,
#          '麻姑': 9,
#          '辟邪': 2,
#          '伎作': 2,
#          '鼓吹': 3,
#          '雉子': 4,
#          '班之': 2,
#          '奏曲': 3,
#          '喔咿': 2,
#          '振迅': 2,
#          '欲飛': 4,
#          '雙雌': 2,
#          '同飲': 2,
#          '趫悍': 2,
#          '誰能': 13,
#          '乍向': 2,
#          '草中': 2,
#          '耿介': 2,
#          '不求': 3,
#          '黃金': 68,
#          '下生': 2,
#          '天地': 47,
#          '廣大': 2,
#          '何惜': 5,
#          '物情': 4,
#          '善卷': 2,
#          '天子': 27,
#          '務光': 2,
#          '逃名': 3,
#          '所貴': 3,
#          '曠士': 2,
#          '朗然': 3,
#          '太清': 11,
#          '垂楊': 8,
#          '綠水': 25,
#          '搖豔': 3,
#          '東風': 20,
#          '花明': 3,
#          '玉關': 14,
#          '葉暖': 2,
#          '金窗': 5,
#          '長恨': 1,
#          '相對': 3,
#          '悽然': 2,
#          '攀條': 3,
#          '春色': 8,
#          '遠寄': 5,
#          '龍庭': 3,
#          '明月': 52,
#          '蒼茫': 6,
#          '雲海': 6,
#          '長風': 20,
#          '幾萬': 4,
#          '吹度': 2,
#          '玉門': 4,
#          '漢下': 2,
#          '白登': 3,
#          '胡窺': 2,
#          '青海': 3,
#          '由來': 12,
#          '不見': 32,
#          '有人': 5,
#          '戍客': 1,
#          '邊色': 2,
#          '思歸': 12,
#          '多苦顏': 3,
#          '高樓': 12,
#          '當此': 3,
#          '歎息': 11,
#          '未應': 5,
#          '彼美': 2,
#          '漢東': 2,
#          '川藏': 1,
#          '寧知': 13,
#          '喪亂': 2,
#          '更有': 4,
#          '一珠': 1,
#          '曉峰': 1,
#          '如畫': 2,
#          '參差': 5,
#          '碑作': 2,
#          '「參': 1,
#          '差碧': 1,
#          '藤影': 1,
#          '風搖': 1,
#          '拂檻': 4,
#          '野徑': 1,
#          '來多': 1,
#          '將犬伴': 1,
#          '人間': 7,
#          '歸晚': 1,
#          '「待」': 1,
#          '看雲': 1,
#          '客倚': 1,
#          '啼猿': 1,
#          '一作': 10,
#          '「鷺」': 1,
#          '或作': 1,
#          '「鶩」': 1,
#          '莫怪': 1,
#          '無心': 11,
#          '清境': 1,
#          '已將': 1,
#          '書劍': 1,
#          '明時': 2,
#          '厄磴': 1,
#          '層層': 1,
#          '太華': 4,
#          '白雲': 36,
#          '深處': 1,
#          '道童': 1,
#          '對月': 1,
#          '吹笛': 1,
#          '仙子': 1,
#          '乘雲': 3,
#          '遠駕': 1,
#          '恠石': 1,
#          '堆山': 1,
#          '如坐': 1,
#          '老藤': 1,
#          '纏樹': 1,
#          '似騰': 1,
#          '曾聞': 2,
#          '玉井': 1,
#          '金河': 1,
#          '會見': 2,
#          '蓬萊': 13,
#          '十丈': 1,
#          '佽飛': 1,
#          '長蛟': 1,
#          '遺圖': 1,
#          '畫中': 1,
#          '登舟': 2,
#          '虎嘯': 3,
#          '激水': 1,
#          '龍戰': 1,
#          '驚波': 3,
#          '拔劍': 3,
#          '雷電': 1,
#          '鱗摧': 1,
#          '白刃': 6,
#          '血染': 1,
#          '滄江': 10,
#          '感此': 6,
#          '古人': 13,
#          '「載」': 1,
#          '本心': 1,
#          '虛空': 4,
#          '清淨': 1,
#          '無一': 6,
#          '焚蕩': 3,
#          '淫怒': 1,
#          '圓寂': 1,
#          '了見': 2,
#          '五綵': 2,
#          '聖像': 1,
#          '悟真': 1,
#          '非妄': 1,
#          '掃雪': 2,
#          '萬病': 1,
#          '爽然': 2,
#          '清凉': 1,
#          '讚此': 1,
#          '功德': 1,
#          '永爲': 1,
#          '曠代': 1,
#          '合沓': 4,
#          '數峰': 1,
#          '奔地': 1,
#          '平楚': 1,
#          '中間': 2,
#          '最高': 1,
#          '髣髴': 3,
#          '接天': 1,
#          '遙望': 4,
#          '九華': 4,
#          '誠然': 1,
#          '蒼顏': 1,
#          '風雪': 1,
#          '奇態': 1,
#          '雲霞': 4,
#          '曜日': 1,
#          '凝成': 1,
#          '凌霄': 1,
#          '增壁': 1,
#          '何當': 10,
#          '餘蔭': 1,
#          '天造': 2,
#          '洞仙': 1,
#          '聞說': 2,
#          '神仙': 11,
#          '葛洪': 1,
#          '煉丹': 1,
#          '曾此': 1,
#          '占雲': 1,
#          '庭前': 3,
#          '廢井': 3,
#          '今猶': 2,
#          '長松': 9,
#          '短松': 1,
#          '頭陀': 3,
#          '萬仞': 1,
#          '遠眺': 1,
#          '華峰': 1,
#          '聊借': 1,
#          '金沙': 4,
#          '洗開': 1,
#          '九芙': 2,
#          '煙嵐': 1,
#          '遍覽': 1,
#          '踏屐': 1,
#          '雙龍': 2,
#          '明日': 9,
#          '登高': 20,
#          '枕月': 1,
#          '青松': 11,
#          '更盡': 1,
#          '聞呼': 1,
#          '恍來': 1,
#          '報曉': 1,
#          '無相': 3,
#          '寺建': 1,
#          '唐初': 1,
#          '道光': 1,
#          '重修': 1,
#          '聖寺': 1,
#          '閑棲': 1,
#          '睡眼': 1,
#          '玉磬': 1,
#          '時聞': 3,
#          '一兩': 1,
#          '朝披': 2,
#          '夢澤': 2,
#          '笠釣': 4,
#          '甲作': 7,
#          '「流」': 1,
#          '乙作': 6,
#          '「綠」': 1,
#          '「二」': 1,
#          '篆字': 1,
#          '若丹蛇': 1,
#          '「遶」': 1,
#          '問天': 1,
#          '戊作': 22,
#          '「姥」': 1,
#          '「妙」': 1,
#          '「刃」': 1,
#          '「紫」': 1,
#          '靈文': 1,
#          '煌煌': 1,
#          '「燕」': 1,
#          '「鐶」': 1,
#          '「想」': 1,
#          '丙作': 2,
#          '「騎」': 1,
#          '「麟」': 1,
#          '海氣': 4,
#          '侵肌': 3,
#          '「喜」': 1,
#          '化作': 3,
#          '梅花': 8,
#          '「遺」': 1,
#          '「非」': 1,
#          '「絡」': 1,
#          '「樓」': 1,
#          '丁作': 1,
#          '「裾」': 1,
#          '「當」': 1,
#          '「璫」': 1,
#          '「揖」': 1,
#          '「予」': 1,
#          '「疾」': 1,
#          '「詞」': 1,
#          '「辭」': 1,
#          '「餘」': 1,
#          '「光': 1,
#          '三韻': 1,
#          '「涼': 1,
#          '二韻': 1,
#          '燭上': 1,
#          '「火」': 1,
#          '春風': 65,
#          '繞樹': 1,
#          '「花」': 1,
#          '「惟」': 1,
#          '「念」': 1,
#          '慘見': 2,
#          '當塗': 3,
#          '「明」': 1,
#          '「上」': 1,
#          '既死': 1,
#          '「彼」': 1,
#          '「瓈」': 1,
#          '念此': 6,
#          '一脫': 1,
#          '「酒」': 1,
#          '「登」': 1,
#          '「鳳」': 1,
#          '星斗': 2,
#          '可捫': 1,
#          '有道': 3,
#          '相訪': 8,
#          '口誦': 1,
#          '此二': 2,
#          '』此': 1,
#          '非世': 2,
#          '人語': 1,
#          '東坡': 1,
#          '定武': 1,
#          '王仲': 1,
#          '弓別': 1,
#          '惠濟': 1,
#          '又出': 1,
#          '曰此': 1,
#          '李真': 1,
#          '人作': 1,
#          '墨跡': 2,
#          '如未': 3,
#          '今莫': 1,
#          '孰是': 1,
#          '眼前': 7,
#          '有景': 1,
#          '道不': 1,
#          '崔顥': 1,
#          '題詩': 3,
#          '在上': 1,
#          '妙有': 1,
#          '二氣': 1,
#          '靈山': 1,
#          '層標': 1,
#          '遲日': 3,
#          '半壁': 2,
#          '明朝': 13,
#          '積雪': 7,
#          '陰壑': 1,
#          '飛流': 3,
#          '陽崖': 1,
#          '青瑩': 1,
#          '玉樹': 10,
#          '縹緲': 2,
#          '羽人': 2,
#          '昔君': 1,
#          '布衣': 3,
#          '與妾': 3,
#          '辛苦': 2,
#          '一拜': 1,
#          '五官': 1,
#          '便索': 1,
#          '邯鄲': 11,
#          '妾欲': 3,
#          '辭君': 8,
#          '君心': 6,
#          '相許': 2,
#          '妾讀': 1,
#          '蘼蕪': 1,
#          '悲歌': 5,
#          '憶昔': 7,
#          '君時': 1,
#          '曾無': 4,
#          '一夜': 7,
#          '不是': 4,
#          '妾無': 1,
#          '君家': 7,
#          '難作': 1,
#          '起來': 3,
#          '強歌': 2,
#          '縱好': 1,
#          '君嫌': 1,
#          '下堂': 1,
#          '去後': 4,
#          '遮莫': 5,
#          '秦樓': 3,
#          '佳麗': 4,
#          '正值': 3,
#          '朝日': 3,
#          '陌頭': 2,
#          '能駐': 1,
#          '花處': 1,
#          '添香': 1,
#          '等閑': 1,
#          '經夏': 1,
#          '經寒': 1,
#          '夢裏': 6,
#          '驚嗟': 1,
#          '暫安': 1,
#          '南家': 1,
#          '風光': 5,
#          '當世': 1,
#          '西陵': 2,
#          '江浪': 1,
#          '過江': 4,
#          '周旋': 4,
#          '小字': 1,
#          '桃燈': 1,
#          '重疊': 1,
#          '遙山': 1,
#          '隔霧': 1,
#          '真是': 1,
#          '爲君': 22,
#          '不得': 19,
#          '書來': 2,
#          '莫說': 1,
#          '更加': 1,
#          '嚴羽': 1,
#          '《滄': 1,
#          '詩話': 1,
#          '「彥': 1,
#          '」形': 1,
#          '近易': 1,
#          '芣苡': 1,
#          '生前': 4,
#          '含桃': 1,
#          '小園': 1,
#          '春心': 3,
#          '搖蕩': 2,
#          '百舌': 1,
#          '更多': 1,
#          '從戎': 1,
#          '邊北': 1,
#          '遠行': 11,
#          '辭密親': 1,
#          '借問': 27,
#          '陰山': 2,
#          '還知': 1,
#          '塞上': 1,
#          '但緊': 1,
#          '接李': 1,
#          '詩後': 1,
#          '於例': 1,
#          '並非': 1,
#          '李白': 5,
#          '磨盡': 1,
#          '石嶺': 1,
#          '潯陽': 4,
#          '赤魚': 1,
#          '靄峯': 1,
#          '似筆': 1,
#          '堪畫': 1,
#          '不堪': 1,
#          '相傳': 4,
#          '太白': 17,
#          '新安': 5,
#          '《九': 1,
#          '域志': 1,
#          '《錦': 1,
#          '繡萬': 1,
#          '花谷': 1,
#          '以爲': 9,
#          '「筆': 1,
#          '」作': 1,
#          '「削」': 1,
#          '黟縣': 1,
#          '小桃': 1,
#          '烟霞': 2,
#          '百里': 11,
#          '地多': 1,
#          '靈草': 1,
#          '人尚': 1,
#          '衣冠': 9,
#          '市向': 1,
#          '晡前散': 1,
#          '山經': 1,
#          '夜後': 1,
#          '皆未': 1,
#          '收此': 1,
#          '今仍': 1,
#          '存之': 1,
#          '夜宿': 1,
#          '烏牙寺': 1,
#          '舉手': 11,
#          '捫星': 1,
#          '不取': 3,
#          '高聲': 1,
#          '恐驚': 1,
#          '天上': 24,
#          '曰李': 1,
#          '李集': 1,
#          '中無': 1,
#          '」又': 1,
#          '《侯': 1,
#          '鯖錄': 1,
#          '王琦': 1,
#          '亦未': 1,
#          '能定': 1,
#          '昔日': 8,
#          '狂秦': 1,
#          '事可': 1,
#          '直驅': 1,
#          '雞犬': 5,
#          '桃花': 28,
#          '「巒」': 1,
#          '潺湲': 6,
#          '「一」': 1,
#          '露暗': 1,
#          '煙濃': 1,
#          '草色': 2,
#          '一翻': 1,
#          '流水': 28,
#          '滿溪': 1,
#          '只見': 2,
#          '天台': 7,
#          '國清': 2,
#          '天下': 20,
#          '四絕': 2,
#          '今到': 1,
#          '普照': 2,
#          '到來': 1,
#          '復何': 3,
#          '「枿」': 1,
#          '高僧': 2,
#          '殘雪': 2,
#          '「前」': 1,
#          '「水」': 1,
#          '幾回': 3,
#          '歲月': 2,
#          '見國': 1,
#          '清院': 1,
#          '碎月': 2,
#          '即此': 2,
#          '篇末': 1,
#          '二句': 1,
#          '蓋未': 1,
#          '全篇': 1,
#          '我來': 17,
#          '舉唐遊': 1,
#          '於中': 1,
#          '更無': 1,
#          '枿木': 1,
#          '劃斷': 1,
#          '高峯': 1,
#          '檻外': 1,
#          '一條': 3,
#          '殷侯': 1,
#          '三玄': 1,
#          '贈我': 7,
#          '栗岡硯': 1,
#          '灑染': 1,
#          '中山': 4,
#          '光映': 1,
#          '吳門': 4,
#          '天寒': 3,
#          '水不': 1,
#          '日用': 1,
#          '心不': 8,
#          '攜此': 1,
#          '墨池': 2,
#          '還如': 3,
#          '嵐光': 2,
#          '深院': 1,
#          '傍砌': 1,
#          '泠泠': 1,
#          '野燕': 1,
#          '官舍': 1,
#          '日斜': 1,
#          '孤吏過': 1,
#          '簾捲': 1,
#          '亂峯': 1,
#          '五色': 10,
#          '焚香': 2,
#          '道經': 3,
#          '刻在': 1,
#          '縣衛': 1,
#          '六即': 1,
#          '潁水': 5,
#          '何慚': 2,
#          '許郡賓': 1,
#          '相逢': 21,
#          '太史': 1,
#          '應是': 3,
#          '賢人': 6,
#          '玉隱': 1,
#          '且在': 1,
#          '蘭枯': 1,
#          '還見': 3,
#          '俄成': 1,
#          '立德': 1,
#          '清真': 7,
#          '熱暖': 1,
#          '將來': 1,
#          '賓鐵文': 1,
#          '暫時': 1,
#          '不動': 2,
#          '撥卻': 1,
#          '青天': 49,
#          '掇頭': 1,
#          '裏許': 1,
#          '便乘': 1,
#          '知見': 1,
#          '一何': 12,
#          '拭眼': 1,
#          '天位': 1,
#          '同觀': 1,
#          '洗耳': 5,
#          '千古': 10,
#          '應無': 1,
#          '石笋': 1,
#          '卓筆': 1,
#          '縣之': 1,
#          '山之': 3,
#          '誰爲': 3,
#          '不平': 1,
#          '與之': 5,
#          '暮跨': 1,
#          '紫鱗': 2,
#          '庭中': 1,
#          '繁樹': 1,
#          '含芳': 1,
#          '紅錦': 2,
#          '重重': 1,
#          '翦作': 1,
#          '還合': 1,
#          '炎蒸': 1,
#          '留爍景': 1,
#          '題來': 1,
#          '渭得': 1,
#          '篇章': 1,
#          '樵夫': 1,
#          '耕者': 1,
#          '出入': 7,
#          '畫屏': 4,
#          '野禽': 1,
#          '杜宇': 1,
#          '山蝶': 1,
#          '莊周': 4,
#          '霜結': 1,
#          '梅梢': 1,
#          '陰凝': 1,
#          '竹幹': 1,
#          '竹粉': 1,
#          '千腰': 1,
#          '桃皮': 1,
#          '頰紅': 1,
#          '心爲': 1,
#          '殺人': 9,
#          '淚是': 1,
#          '報恩': 3,
#          '佳人': 10,
#          '微醉': 1,
#          '玉顏': 12,
#          '笑伾': 1,
#          '粧樓': 1,
#          '澹小蛾': 1,
#          '單樓': 1,
#          '同穴': 1,
#          '可能': 1,
#          '銀漢': 3,
#          '重泉': 1,
#          '舉頭': 2,
#          '忽見': 7,
#          '衡陽': 1,
#          '千聲': 1,
#          '萬字': 1,
#          '何限': 1,
#          '叵耐': 1,
#          '薄情': 1,
#          '一行': 9,
#          '也無': 2,
#          '泣歸': 1,
#          '香閣': 2,
#          '和淚': 1,
#          '紅粉': 5,
#          '待雁': 1,
#          '却回': 1,
#          '書寄': 1,
#          '《尊': 1,
#          '前集': 1,
#          '大雅': 4,
#          '久不': 3,
#          '吾衰': 1,
#          '竟誰': 6,
#          '王風': 2,
#          '蔓草': 6,
#          '戰國': 3,
#          '荆榛': 1,
#          '龍虎': 16,
#          '相啖食': 1,
#          '兵戈': 2,
#          '逮狂': 1,
#          '正聲': 1,
#          '微茫': 4,
#          '哀怨': 2,
#          '騷人': 2,
#          '揚馬': 1,
#          '頹波': 2,
#          '開流': 1,
#          '無垠': 2,
#          '廢興': 1,
#          '萬變': 1,
#          '憲章': 1,
#          '亦已': 4,
#          '自從': 6,
#          '建安': 2,
#          '綺麗': 1,
#          '聖代': 3,
#          '復元古': 1,
#          '垂衣': 1,
#          '羣才': 3,
#          '休明': 5,
#          '乘運': 1,
#          '共躍鱗': 1,
#          '文質': 1,
#          '炳煥': 2,
#          '衆星': 3,
#          '秋旻': 1,
#          '我志': 1,
#          '刪述': 1,
#          '垂輝': 1,
#          '千春': 5,
#          '希聖': 1,
#          '如有': 8,
#          '絕筆': 1,
#          '獲麟': 2,
#          '蟾蜍': 3,
#          '蝕此': 1,
#          '瑤臺': 15,
#          '圓光': 3,
#          '中天': 5,
#          '金魄': 1,
#          '淪沒': 3,
#          '螮蝀': 1,
#          '紫微': 8,
#          '大明': 2,
#          '朝暉': 1,
#          '浮雲': 40,
#          '兩曜': 1,
#          '萬象': 4,
#          '昏陰': 1,
#          '蕭蕭': 4,
#          '長門': 9,
#          '昔是': 1,
#          '今已': 5,
#          '桂蠹': 1,
#          '花不': 2,
#          '天霜': 5,
#          '嚴威': 1,
#          '沈歎': 1,
#          '永夕': 2,
#          '感我': 1,
#          '沾衣': 1,
#          '秦皇': 4,
#          '六合': 11,
#          '虎視': 1,
#          '雄哉': 1,
#          '飛劒': 1,
#          '諸侯': 5,
#          '明斷': 1,
#          '自天': 2,
#          '大略': 1,
#          '收兵': 1,
#          '鑄金': 1,
#          '函谷': 6,
#          '正東': 2,
#          '銘功': 1,
#          '會稽': 12,
#          '騁望': 1,
#          '瑯琊': 2,
#          '刑徒': 1,
#          '七十': 8,
#          '起土': 1,
#          '驪山': 1,
#          '尚採': 1,
#          '不死': 5,
#          '茫然': 11,
#          '使心': 1,
#          '連弩': 1,
#          '海魚': 1,
#          '崔嵬': 6,
#          '額鼻': 1,
#          '五嶽': 7,
#          '揚波': 3,
#          '噴雲': 1,
#          '鬐鬣': 1,
#          '何由': 10,
#          '樓船': 18,
#          '幾時': 15,
#          '但見': 7,
#          '三泉': 1,
#          '金棺': 1,
#          '寒灰': 5,
#          '鳳飛': 1,
#          '九千': 3,
#          '五章': 2,
#          '備綵珍': 1,
#          '銜書': 2,
#          '虛歸': 1,
#          '空入': 1,
#          '周與秦': 3,
#          '橫絕': 4,
#          '四海': 14,
#          '所居': 2,
#          '未得': 4,
#          '吾營': 1,
#          '紫河': 2,
#          '千載': 14,
#          '風塵': 11,
#          '藥物': 2,
#          '海嶽': 3,
#          '採鉛': 1,
#          '青溪': 2,
#          '時登': 2,
#          '大樓': 2,
#          '望仙': 1,
#          '羽駕': 1,
#          '滅去': 1,
#          '飆車': 1,
#          '絕廻輪': 1,
#          '尚恐': 1,
#          '丹液': 2,
#          '志願': 1,
#          '徒霜': 1,
#          '鏡中': 6,
#          '羞彼': 1,
#          '上人': 2,
#          '何處': 23,
#          '此花': 1,
#          '非我': 2,
#          '唯應': 1,
#          '清都': 3,
#          '長與': 2,
#          '韓衆': 2,
#          '蒼蒼': 12,
#          '星辰': 5,
#          '森列': 1,
#          '去天': 4,
#          '邈爾': 1,
#          '與世': 2,
#          '中有': 7,
#          '綠髮': 2,
#          '披雲': 3,
#          '松雪': 7,
#          '不笑': 1,
#          '亦不': 6,
#          '冥棲': 2,
#          ...})

# %%
result_li.most_common(10)
# Out:
# [('不可', 75),
#  ('黃金', 68),
#  ('春風', 65),
#  ('萬里', 60),
#  ('白日', 57),
#  ('明月', 52),
#  ('青天', 49),
#  ('相思', 49),
#  ('天地', 47),
#  ('青雲', 44)]

# %%
def tang_author_topK(author,K):
    author_seg = tang_df[tang_df['author']==author]['dic_total'].tolist()
    author_list = reduce(operator.add, author_seg) 
    result_author = Counter(author_list)
    return  result_author.most_common(K)

# %%
tang_author_topK('李白',10)
# Out:
# [('不可', 75),
#  ('黃金', 68),
#  ('春風', 65),
#  ('萬里', 60),
#  ('白日', 57),
#  ('明月', 52),
#  ('青天', 49),
#  ('相思', 49),
#  ('天地', 47),
#  ('青雲', 44)]

# %%
def song_author_topK(author,K):
    author_seg = song_df[song_df['author']==author]['dic_total'].tolist()
    author_list = reduce(operator.add, author_seg) 
    result_author = Counter(author_list)
    return  result_author.most_common(K)

# %%
song_author_topK('苏轼',10)
# Out:
# [('归去', 44),
#  ('何处', 39),
#  ('使君', 28),
#  ('佳人', 26),
#  ('人间', 23),
#  ('明月', 22),
#  ('江南', 20),
#  ('尊前', 20),
#  ('千里', 19),
#  ('风流', 18)]

# %% [markdown]
# ### 唐朝诗人关系网络创建，并存储在save文件夹中

# %%
import pickle
import sqlite3
from collections import Counter, defaultdict

# %%
def combine_list(list_df):
    s=''
    return s.join(list_df)

# %%
tang_df['paragraphs_t']=tang_df['paragraphs'].apply(lambda x:combine_list(x))

# %%
# TODO 补充著名诗人列表
# 這些詩人在CBDB的重名难以轻易排除，手動查找其在BIOG_MAIN表中的ID
# 注意CBDB使用的是繁體中文
manual_defuzzy_authors_id = {
    '李林甫': 32534, '王建': 92047,
    '李賀': 93012, '張繼': 93495,
    '張旭': 93409, '李紳': 92982}
# 手動刪除某些作者
mannual_deleted_authors = set(['無作', '清江'])
# 手動刪除作者的某些別稱，这些别称在唐诗中是常用字
mannual_deleted_alter_names = {'李林甫': set(['李十']),
    '李益': set(['李十']),
    '李世民': set(['李二']),
    '李嘉祐': set(['李二']),
    '馬湘': set(['自然']),
    '高駢': set(['千里']),
    '孟浩然': set(['浩然']),
    '李白': set(['太白']),
    '黃巢': set(['皇帝']),
    '眉娘': set(['逍遙'])}
# 補充CBDB中缺少的部分作者別稱
mannual_added_alter_names = {
    '李建': set(['李十一']),
    '劉禹錫': set(['劉二十八'])
    }

# %%
def read_poem(p_dataframe, p_type='tang'):
    if p_type=='tang':
        authors_set=set(p_dataframe['author'])
        poem_list= p_dataframe[['author','title','paragraphs_t']].values.tolist()
    if p_type=='song':
        authors_set=set(p_dataframe['author'])
        poem_list= p_dataframe[['author','rhythmic','paragraphs_t']].values.tolist()
    return authors_set,poem_list

# %%
def get_alter_names(qts_file, cbdb_file, save_dir,p_type='tang'):
    alter_names_file = os.path.join(save_dir, "alternames.pkl")

    if os.path.exists(alter_names_file):
        print("find dumped alternames file, loading directly.")
        with open(alter_names_file, 'rb') as f:
            qts_list, authors_filtered_by_CBDB, alter_names_dict = pickle.load(f)
    else:
        print("processing QuanTangShi...")
        # 读取全唐诗，并存储诗歌内容和作者
        authors_set, qts_list  = read_poem(qts_file,p_type)
        # 删除部分作者
        authors_set = authors_set - mannual_deleted_authors

        alter_names_dict, authors_filtered_by_CBDB = get_alter_names_from_CBDB(cbdb_file, authors_set,
                                                                               manual_defuzzy_authors_id,p_type)
        # 刪除不想要的別稱
        for k, v in mannual_deleted_alter_names.items():
            alter_names_dict[k] -= v
        # 補充CBDB中缺少的別稱
        for k, v in mannual_added_alter_names.items():
            alter_names_dict[k] |= v

        # 存储计算结果
        with open(alter_names_file, 'wb') as f:
            pickle.dump([qts_list, authors_filtered_by_CBDB, alter_names_dict], f)

    return qts_list, authors_filtered_by_CBDB, alter_names_dict

# %%
def get_refer_relations(qts_list, authors_filtered_by_CBDB, alter_names_dict, save_dir):
    reference_relations_file = os.path.join(save_dir, 'reference_relations.pkl')

    if os.path.exists(reference_relations_file):
        print("find dumped reference relations file, skip calculating.")
        return
    else:
        print("calculating reference relations...")
    reference_relations_counter = Counter()
    reference_relations_text = defaultdict(list)
    # 逐个作者搜寻
    for name in authors_filtered_by_CBDB:
        # 逐首诗搜寻
        for author, title, text in qts_list:
            # 如果不在CBDB过滤过的set中，直接跳过
            if author not in authors_filtered_by_CBDB:
                continue
            poem = title + ' ' + text
        
            # 查找本名，标题加正文中只要出现一次名字就可以
            if poem.find(name) != -1:
                reference_relations_counter[(author, name)] += 1
                reference_relations_text[(author, name)].append(title)
                continue
            # 查找别名
            alt_names = alter_names_dict[name]
            for alt_name in alt_names:
                if poem.find(alt_name) != -1:
                    reference_relations_counter[(author, name)] += 1
                    reference_relations_text[(author, name)].append(title)
                    break
    # 存储计算结果
    with open(reference_relations_file, 'wb') as f:
        pickle.dump([reference_relations_counter, reference_relations_text], f)

# %%
# 从CBDB中获取诗人们的别名
def get_alter_names_from_CBDB(db_file, authors_set, manual_defuzzy_authors_id,p_type='tang'):
    if p_type=='tang':
        tang_begin_year = 618  # 唐朝建立年份
        tang_end_year = 907  # 唐朝灭亡年份
    if p_type=='song':
        tang_begin_year = 960  # 唐朝建立年份
        tang_end_year = 1279  # 唐朝灭亡年份

    # 手动排查的诗人集合
    mannual_defuzzy_authors = set(manual_defuzzy_authors_id.keys())

    authors_not_in_CBDB = set()
    fuzzy_authors = set()
    fuzzy_authors_details = {}
    alter_names_dict = defaultdict(set)

    conn = sqlite3.connect(db_file)
    cursor = conn.cursor()
    for author in authors_set:
        # 如果在手动排查集合中，直接使用
        if author in mannual_defuzzy_authors:
            author_id = manual_defuzzy_authors_id[author]
        else: # 否则从CBDB中查询
          # import ipdb; ipdb.set_trace()
          # 某些诗人的名字在全唐诗中和CBDB中不一致，用模糊搜索更好
          # 比如"贯休"在CBDB中的名字为"释贯休"
            author_pattern = '%' + author
            cursor.execute('SELECT c_personid, c_birthyear, c_deathyear FROM BIOG_MAIN WHERE c_name_chn LIKE?',
                         (author_pattern,))
            person_info_list = cursor.fetchall()

      # 排除重名现象
      # 具体策略请参考我的微信公众号(mrqianjinsi)文章《计算机告诉你，唐朝诗人之间的关系到底是什么样的？》
        candidate_author_ids = []
        # import ipdb; ipdb.set_trace()
        for person_id, birth_year, death_year in person_info_list:
            if birth_year and death_year:  # 生卒年俱全
                if birth_year < tang_end_year and death_year > tang_begin_year:
                # 一旦找到一个生卒年俱全且和唐朝有交集的，就不看其他的了
                    candidate_author_ids = [person_id]
                    break
            elif birth_year or death_year:  # 只有生年或者卒年
                year = birth_year if birth_year else death_year
                if year > tang_begin_year and year < tang_end_year:
                    candidate_author_ids.append(person_id)

        # 候选名单为空或者多于一个人的候选名单都不要
        if not candidate_author_ids:
            authors_not_in_CBDB.add(author)
            # print('can\'t find valid items for %s' % author)
            continue
        elif len(candidate_author_ids) > 1:
            fuzzy_authors.add(author)
            fuzzy_authors_details[author] = candidate_author_ids
            # print('fuzzy authors: %s' % author)
            continue

        author_id = candidate_author_ids[0]

    # 根据author_id找出诗人别名
    cursor.execute('SELECT c_alt_name_chn FROM ALTNAME_DATA WHERE c_personid=?',
                   (author_id,))
    alt_name_list = cursor.fetchall()
    for alt_name in alt_name_list:
      # 不要只有一个字的别称
      if len(alt_name[0]) > 1:
        alter_names_dict[author].add(alt_name[0])

    conn.close()

  # 经过CBDB过滤过的诗人，接下来只分析这些人之间的关系
    authors_filtered_by_CBDB = authors_set - authors_not_in_CBDB - fuzzy_authors

    return alter_names_dict, authors_filtered_by_CBDB

# %%
qts_list, authors_filtered_by_CBDB, alter_names_dict = get_alter_names(tang_df, 'data/cbdb_sqlite.db', 'save')
get_refer_relations(qts_list, authors_filtered_by_CBDB, alter_names_dict, 'save')
# Out:
# find dumped alternames file, loading directly.
# calculating reference relations...

# %% [markdown]
# ### 读取网络进行可视化

# %%
import os
import math

# 如果需要，可以用opencc实现繁体和简体之间的转换
# 需要在电脑上安装opencc
# opencc = 'opencc -i echart_visualize/poets_network_early.html -o echart_visualize/poets_network_early_zhs.html -c zht2zhs.ini'


# 直接获取排名前visulize_range的引用关系
def get_concerned_relations_by_range(reference_relations_counter, visualize_range):
    # 获取引用关系
    relations = reference_relations_counter.most_common(visualize_range)

    max_refer_count = relations[0][1]
    min_refer_count = relations[-1][1]

    return relations, max_refer_count, min_refer_count

# 获取指定诗人群体之间的引用关系，适合画出某个群体内部的网络
def get_concerned_relations_by_authors(reference_relations_counter, authors):
    # 获取指定作者群体内部的引用关系
    relations = []
    max_refer_count = 0
    min_refer_count = 10000
    for (refered_by, refered), count in reference_relations_counter.items():
        # 不统计自引用的count
        if refered_by == refered:
            continue
        if refered_by in authors and refered in authors:
            if count > max_refer_count:
                max_refer_count = count
            if count < min_refer_count:
                min_refer_count = count

            relations.append(((refered_by, refered), count))

    return relations, max_refer_count, min_refer_count

# 有些时候如果画出所有关系会显得非常拥挤，用count_to_plot_threshold来控制最小显示出来的关系
# 只有引用数大于等于count_to_plot_threshold的关系才会显示出来
def generate_html_page(relations, max_refer_count, min_refer_count, saved_html_file, count_to_plot_threshold = 1):
    html_dir = os.path.dirname(saved_html_file)
    html_head_path = os.path.join(html_dir, 'html_head.txt')
    html_tail_path = os.path.join(html_dir, 'html_tail.txt')

    min_link_width = 0.5
    max_link_width = 3.0

    # 因为引用关系的强弱范围很大，对其开方降低变化范围，画图更直观
    max_refer_count = math.sqrt(max_refer_count)
    min_refer_count = math.sqrt(min_refer_count)
    width_slope = (max_link_width - min_link_width) / (max_refer_count - min_refer_count)
    # 格式化links数据
    links_text = 'links: [\n'
    links_item_format = """{source: '%s', target: '%s',
    lineStyle:{normal:{width: %f}}},
    """
    filtered_authors = set()
    for (refered_by, refered), count in relations:
        # 跳过自引用，不然有可能画出孤立节点
        if refered_by == refered:
            continue
        # 小于门限跳过
        if count < count_to_plot_threshold:
            continue

        filtered_authors.add(refered_by)
        filtered_authors.add(refered)
        count = math.sqrt(count)
        line_width = min_link_width + width_slope * (count - min_refer_count)
        links_text += links_item_format % (refered_by, refered, line_width)

    links_text += '],\n'

    # 格式化node数据
    data_text = 'data:[\n'
    data_item_format = "{name: '%s'},\n"
    for author in filtered_authors:
        data_text += data_item_format % author

    data_text += '],\n'

    # 读取html的head和tail部分
    with open(html_head_path, 'r', encoding = 'utf-8') as f:
        head_text = f.read()

    with open(html_tail_path, 'r', encoding = 'utf-8') as f:
        tail_text = f.read()

    # 合并存储为html
    with open(saved_html_file, 'w', encoding = 'utf-8') as f:
        f.write(head_text + data_text + links_text + tail_text)

# %%
with open('save/reference_relations.pkl', 'rb') as f:
        
        reference_relations_counter, reference_relations_text = pickle.load(f)
    
# 生成全唐排名前100的关系图
relations, max_refer_count, min_refer_count = get_concerned_relations_by_range(reference_relations_counter, 100)
saved_html = os.path.join('html', 'full_tang_poets_net.html')
generate_html_page(relations, max_refer_count, min_refer_count, saved_html)

# 生成初唐、盛唐、中唐、晚唐四个时期的诗人关系图
#                      诗人名字文件              社交关系图网页              引用数门限
files_name_array = [('early_tang_poets.txt', 'early_tang_poets_net.html',  1),
                  ('high_tang_poets.txt',  'high_tang_poets_net.html',   2),
                  ('middle_tang_poets.txt','middle_tang_poets_net.html', 2),
                  ('late_tang_poets.txt',  'late_tang_poets_net.html',   1)]

for authors_file_name, html_file_name, threshold in files_name_array:
    authors_file_path = os.path.join('data', authors_file_name)
    with open(authors_file_path, 'r', encoding='utf-8') as f:
        text = f.read()
    authors = set(text.split())

    relations, max_refer_count, min_refer_count = get_concerned_relations_by_authors(reference_relations_counter, authors)

    saved_html = os.path.join("html", html_file_name)
    generate_html_page(relations, max_refer_count, min_refer_count, saved_html, threshold)

# %% [markdown]
# ### 宋朝诗人网络创建

# %%
qts_list, authors_filtered_by_CBDB, alter_names_dict = get_alter_names(song_df, 'data/cbdb_sqlite.db', 'song_save','song')
get_refer_relations(qts_list, authors_filtered_by_CBDB, alter_names_dict, 'song_save')
# Out:
# processing QuanTangShi...
# calculating reference relations...

# %%
with open('song_save/reference_relations.pkl', 'rb') as f:
        
        reference_relations_counter, reference_relations_text = pickle.load(f)
    
# 生成全宋排名前100的关系图
relations, max_refer_count, min_refer_count = get_concerned_relations_by_range(reference_relations_counter, 100)
saved_html = os.path.join('html', 'full_song_poets_net.html')
generate_html_page(relations, max_refer_count, min_refer_count, saved_html)
