# %% [markdown]
# # 分词部分

# %%
import os 
import re

import jieba
import json
import pandas as pd

# %%
### ONLY FOR TEST
def test_segmentation(poem, user_dict=None):   
    for s in poem:
        seg_list = jieba.cut(s, cut_all=False)  
        print('/'.join(list(seg_list)))
        
def run_test_1(user_dict=None):
    poem = ['秦川雄帝宅，函谷壯皇居。', '綺殿千尋起，離宮百雉餘。', '連甍遙接漢，飛觀迥凌虛。', '雲日隱層闕，風煙出綺疎。']
    print('Poem #1')
    test_segmentation(poem, user_dict)
    
    poem = ['遠山媚平楚，宿雨漲清溪。', '沿泝任舟檝，歡言無町畦。', '夜深忽梦少年事，梦啼妆泪红阑干']
    print('Poem #2')
    test_segmentation(poem, user_dict)
    
    poem = ['剑外忽传收蓟北，初闻涕泪满衣裳。',
            '却看妻子愁何在，漫卷诗书喜欲狂。',
            '白日放歌须纵酒，青春作伴好还乡。',
            '即从巴峡穿巫峡，便下襄阳向洛阳。']
    print('Poem #3')
    test_segmentation(poem, user_dict)
    
    poem = ['明月几时有，把酒问青天。', '不知天上宫阙，今夕是何年。', '我欲乘风归去，又恐琼楼玉宇，高处不胜寒。', '起舞弄清影，何似在人间。',
              '转朱阁，低绮户，照无眠。', '不应有恨，何事长向别时圆。', '人有悲欢离合，月有阴晴圆缺，此事古难全。', '但愿人长久，千里共婵娟。']
    print('Poem #4')
    test_segmentation(poem, user_dict)

# %%
LYRIC_DIR = './ci/'
POEM_DIR = './json/'

# %% [markdown]
# ## 唐诗

# %% [markdown]
# 先测试一下jieba分词的原始分词功能，以下诗句明显分错：
# + 秦川/雄帝/宅/
# + 沿/泝/任舟/檝/，/歡言/無/町/畦/
# + /月/有/阴晴圆/缺/

# %%
run_test_1()
# Out:
# Building prefix dict from the default dictionary ...
# Poem #1
# Dumping model to file cache C:\Users\JUNHONG\AppData\Local\Temp\jieba.cache
# Loading model cost 0.584 seconds.
# Prefix dict has been built successfully.
# 秦川/雄帝/宅/，/函谷壯/皇居/。
# 綺/殿/千尋起/，/離宮/百雉/餘/。
# 連/甍/遙/接漢/，/飛觀/迥凌虛/。
# 雲日/隱層/闕/，/風煙出/綺/疎/。
# Poem #2
# 遠山媚/平楚/，/宿雨漲/清溪/。
# 沿/泝/任舟/檝/，/歡言/無/町/畦/。
# 夜深/忽梦/少年/事/，/梦啼妆泪/红/阑干
# Poem #3
# 剑外/忽/传收/蓟北/，/初闻/涕泪/满/衣裳/。
# 却/看/妻子/愁/何在/，/漫卷/诗书/喜欲狂/。
# 白日/放歌/须/纵酒/，/青春/作伴/好/还乡/。
# 即/从/巴峡/穿/巫峡/，/便/下/襄阳/向/洛阳/。
# Poem #4
# 明月/几时/有/，/把酒/问青天/。
# 不知/天上/宫阙/，/今夕/是/何年/。
# 我/欲/乘风/归去/，/又/恐/琼楼玉宇/，/高处不胜/寒/。
# 起舞/弄清/影/，/何似/在/人间/。
# 转朱阁/，/低绮户/，/照无眠/。
# 不/应有/恨/，/何事/长向/别时圆/。
# 人有/悲欢离合/，/月/有/阴晴圆/缺/，/此事/古难全/。
# 但愿人长久/，/千里/共/婵娟/。

# %% [markdown]
# 接下来我的想法是，先根据五字句的前两个字和七字句的前四个字构建词典，然后以此作为分词词典对整句进行分词。
#
# 我用了全唐诗和全宋诗作为数据集来构建词典。经测试，比只使用全唐诗更加精确。

# %%
poems = []
file_list = os.listdir(POEM_DIR)
for file in file_list:
    if file.startswith('poet.'):
        poems.append(pd.read_json(f'{POEM_DIR}{file}'))
poem_df = pd.concat(poems, ignore_index=True)

# %%
def cut_lines(poem):
    lines = []
    pattern = r',|\.|/|;|\'|`|\[|\]|<|>|\?|:|"|\{|\}|\~|!|@|#|\$|%|\^|&|\(|\)|-|=|\_|\+|，|。|、|；|‘|’|【|】|·|！| |…|（|）'
    for pairs in poem:
        lines.extend(list(filter(lambda x: len(x) > 0, re.split(pattern, pairs))))
    return lines

# %%
poem_df['lines'] = poem_df['paragraphs'].apply(cut_lines)

# %%
def first_segment(lines):
    words = []
    for line in lines:
        if len(line) == 5: 
            words.append(line[0:2])
        if len(line) == 7: 
            words.append(line[0:2])
            words.append(line[2:4])
    return words

# %%
poem_df['dic'] = poem_df['lines'].apply(first_segment)

# %%
word_freq = dict()

dictionary = [item for sublist in poem_df['dic'] for item in sublist]
for i in dictionary:
    word_freq[i] = word_freq.get(i, 0) + 1

word_freq = {key:val for key, val in word_freq.items() if val >= 3}

with open('./poem_dict.txt', 'w', encoding='utf-8') as f:
    for k, v in word_freq.items():
        f.write(f'{k} {v}\n')

jieba.set_dictionary('./poem_dict.txt')

# %% [markdown]
# 测试目前词典的分词效果。可见之前使用原始词典分错的地方都能分对，但是也添加了几处错误：
# + /梦啼妆泪/红/阑/干
# + /初闻涕/泪满/衣裳/
# + 我欲/乘风/归/去/
#
# 但是目前我们只关心唐诗的五字句和七字句的后三个字的分词，所以可以认为效果明显变好，毕竟“雄/帝宅”，“任/舟檝”，“無/町畦”等都能分对。

# %%
run_test_1()
# Out:
# Building prefix dict from C:\Users\JUNHONG\history-digital\poem_dict.txt ...
# Poem #1
# Dumping model to file cache C:\Users\JUNHONG\AppData\Local\Temp\jieba.u8c6200af4b343395bea15d660881757b.cache
# Loading model cost 0.225 seconds.
# Prefix dict has been built successfully.
# 秦川/雄/帝宅/，/函谷/壯/皇居/。
# 綺/殿/千尋/起/，/離宮/百雉/餘/。
# 連甍/遙接漢/，/飛觀/迥/凌虛/。
# 雲日/隱層/闕/，/風煙/出/綺疎/。
# Poem #2
# 遠山/媚/平楚/，/宿雨/漲/清溪/。
# 沿泝/任/舟檝/，/歡言/無/町畦/。
# 夜深/忽梦/少年/事/，/梦啼妆泪/红/阑/干
# Poem #3
# 剑外/忽/传收/蓟北/，/初闻涕/泪满/衣裳/。
# 却看/妻子/愁/何在/，/漫卷/诗书/喜欲狂/。
# 白日/放歌/须/纵酒/，/青春/作伴/好/还/乡/。
# 即/从/巴峡/穿/巫峡/，/便下/襄阳/向/洛阳/。
# Poem #4
# 明月/几时/有/，/把酒/问/青天/。
# 不知/天上/宫阙/，/今夕/是何/年/。
# 我欲/乘风/归/去/，/又恐/琼楼/玉宇/，/高处/不胜寒/。
# 起舞/弄/清影/，/何似/在人/间/。
# 转朱阁/，/低绮户/，/照无眠/。
# 不应/有恨/，/何事/长向别/时/圆/。
# 人有/悲欢/离合/，/月有/阴晴/圆缺/，/此事/古难全/。
# 但愿/人长/久/，/千里/共婵娟/。

# %% [markdown]
# 之后根据词典对后三个字再次进行分词，并据此扩充词典：

# %%
def addition_segment(phrase):
    result = jieba.lcut(phrase, cut_all=False)     
    if len(result) != 2:
        return phrase
    if len(result[0]) == 2:
        return result[0]
    return result[1]

def second_segment(lines):
    words = []
    for line in lines:
        if len(line) == 5:
            words.append(line[0:2])
            words.append(addition_segment(line[2:]))
        if len(line) == 7:
            words.append(line[0:2])
            words.append(line[2:4])
            words.append(addition_segment(line[4:]))
    return words

# %%
poem_df['dic_total'] = poem_df['lines'].apply(second_segment)

# %%
word_freq = dict()
dictionary = [item for sublist in poem_df['dic_total'] for item in sublist]
for i in dictionary:
    word_freq[i] = word_freq.get(i, 0) + 1

word_freq = {key:val for key, val in word_freq.items() if val >= 3}

with open('./whole_poem_dict.txt', 'w', encoding='utf-8') as f:
    for k, v in word_freq.items():
        f.write(f'{k} {v}\n')

jieba.set_dictionary('./whole_poem_dict.txt')

# %% [markdown]
# 第二次的分词效果如下，可见效果再次变好，我觉得和上次的分词效果相当，虽然修正了“初闻/涕泪/满/衣裳”，但是“却看/妻子/愁何/在”又分错了。

# %%
run_test_1()
# Out:
# Building prefix dict from C:\Users\JUNHONG\history-digital\whole_poem_dict.txt ...
# Poem #1
# Dumping model to file cache C:\Users\JUNHONG\AppData\Local\Temp\jieba.u62ee47001558428dfaffbfcc81625e42.cache
# Loading model cost 0.274 seconds.
# Prefix dict has been built successfully.
# 秦川/雄/帝宅/，/函谷/壯/皇居/。
# 綺/殿/千尋/起/，/離宮/百雉/餘/。
# 連甍/遙接漢/，/飛觀/迥/凌虛/。
# 雲日/隱層/闕/，/風煙/出/綺疎/。
# Poem #2
# 遠山/媚/平楚/，/宿雨/漲/清溪/。
# 沿泝/任/舟檝/，/歡言/無/町畦/。
# 夜深/忽梦/少年/事/，/梦啼妆泪/红/阑/干
# Poem #3
# 剑外/忽/传收/蓟北/，/初闻/涕泪/满/衣裳/。
# 却看/妻子/愁何/在/，/漫卷/诗书/喜欲狂/。
# 白日/放歌/须/纵酒/，/青春/作伴/好/还/乡/。
# 即/从/巴峡/穿/巫峡/，/便下/襄阳/向/洛阳/。
# Poem #4
# 明月/几时/有/，/把酒/问/青天/。
# 不知/天上/宫阙/，/今夕/是何/年/。
# 我欲/乘风/归/去/，/又恐/琼楼/玉宇/，/高处/不胜寒/。
# 起舞/弄/清影/，/何似/在人/间/。
# 转朱阁/，/低绮户/，/照无眠/。
# 不应/有恨/，/何事/长向别/时/圆/。
# 人有/悲欢/离合/，/月有/阴晴/圆缺/，/此事/古难全/。
# 但愿/人长/久/，/千里/共婵娟/。

# %% [markdown]
# 总结，jieba分词很有问题，词典中单词的频率并不能有效改善分词结果。比如在自定义的词典中，明明没有“愁何”，而且“何在”出现了很多次，但jieba仍然分成了“愁何/在”。
#
# jieba的这个问题已经讨论了好几年了：
# https://github.com/fxsjy/jieba/issues/14

# %% [markdown]
# ## 宋词

# %% [markdown]
# 我本想人工划分意向，但有些名句出现得太例外：
# + 六字句通常划分方式各异，最常见的为222式，但有的名句与众不同：七八个星天外，两三点雨山前。
# + “满江红”此句与别句的划分方式都不同：“驾长车，踏破贺兰山缺”，加之“贺兰山”是地名，故最好不要人工划分。
#
# 所以只能重回之前用的套路，先提取五字句中的前两个字和七字句中的前四字扩充词典，再根据扩充后的词典分词。

# %%
lyrics = []
file_list = os.listdir(LYRIC_DIR)
for file in file_list:
    if file.startswith('ci.song'):
        lyrics.append(pd.read_json(f'{LYRIC_DIR}{file}'))
lyric_df = pd.concat(lyrics, ignore_index=True)
lyric_df
# Out:
#       author                                         paragraphs rhythmic tags  \
# 0         和岘  [气和玉烛，睿化著鸿明。, 缇管一阳生。, 郊禋盛礼燔柴毕，旋轸凤凰城。, 森罗仪卫振华缨。...       导引  NaN
# 1         和岘  [严夜警，铜莲漏迟迟。, 清禁肃，森陛戟，羽卫俨皇闱。, 角声励，钲鼓攸宜。, 金管成雅奏，...       六州  NaN
# 2         和岘  [承宝运，驯致隆平。, 鸿庆被寰瀛。, 时清俗阜，治定功成。, 遐迩咏由庚。, 严郊祀，文物...  十二时・忆少年  NaN
# 3         王禹  [雨恨云愁，江南依旧称佳丽。, 水村渔市。, 一缕孤烟细。, 天际征鸿，遥认行如缀。, 平生...      点绛唇  NaN
# 4        苏易简   [神仙神仙瑶池宴。, 片片。, 碧桃零落春风晚。, 翠云开处，隐隐金舆挽。, 玉麟背冷清风远。]      越江吟  NaN
# ...      ...                                                ...      ...  ...
# 21048    范成大  [催下珠帘护绮丛。, 花枝红里烛枝红。, 烛光花影夜葱茏。, 锦地绣天香雾里，珠星璧月彩云中...      浣溪沙  NaN
# 21049    范成大  [送尽残春更出游。, 风前踪迹似沙鸥。, 浅斟低唱小淹留。, 月见西楼清夜醉，雨添南浦绿波愁...      浣溪沙  NaN
# 21050    范成大  [歙浦钱塘一水通。, 闲云如幕碧重重。, 吴山应在碧云东。, 无力海棠风淡荡，半眠官柳日葱茏...      浣溪沙  NaN
# 21051    范成大  [宝髻双双出绮丛。, 妆光梅影各春风。, 收灯时候却相逢。, 鱼子笺中此宛转，龙香拨上语玲珑...      浣溪沙  NaN
# 21052    范成大  [红锦障泥杏叶鞯。, 解鞍呼渡忆当年。, 马骄不肯上航船。, 茅店竹篱开席市，绛裙青袂斸姜田...      浣溪沙  NaN
#
#       prologue
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 21048      NaN
# 21049      NaN
# 21050      NaN
# 21051      NaN
# 21052      NaN
#
# [21053 rows x 5 columns]

# %% [markdown]
# 词牌名概览。出现次数最多的15个词牌名占了宋词的三分之一：

# %%
rhythm_df = lyric_df.groupby(['rhythmic']).count()
rhythm_df.sort_values(by='paragraphs', ascending=False).head(15)
# Out:
#           author  paragraphs  tags  prologue
# rhythmic
# 浣溪沙          776         776    16         1
# 水调歌头         743         743    45         0
# 鹧鸪天          657         657    19         0
# 菩萨蛮          598         598     9         0
# 满江红          549         549    30         0
# 西江月          490         490     7         2
# 临江仙          482         482    13         0
# 念奴娇          432         432    28         0
# 减字木兰花        425         425     4         0
# 沁园春          423         423    28         0
# 蝶恋花          416         416    16         0
# 点绛唇          390         390     7         2
# 失调名          372         372     3         0
# 贺新郎          361         361    37         0
# 清平乐          356         356     8         0

# %%
lyric_df['lines'] = lyric_df['paragraphs'].apply(cut_lines)

# %%
lyric_df['dic'] = lyric_df['lines'].apply(first_segment)
lyric_df['dic']
# Out:
# 0        [睿化, 缇管, 郊禋, 盛礼, 旋轸, 森罗, 仪卫, 载路, 皇图, 大业, 垂象, 九...
# 1                         [铜莲, 羽卫, 金管, 属景, 盛德, 三秀, 合尧, 蹈咏]
# 2        [鸿庆, 遐迩, 星拱, 布羽, 明德, 神降, 万乘, 肃銮, 玉帛, 皇泽, 普率, 睿...
# 3                                     [江南, 依旧, 一缕, 遥认, 谁会]
# 4                             [神仙, 神仙, 碧桃, 零落, 隐隐, 玉麟, 背冷]
#                                ...
# 21048     [催下, 珠帘, 花枝, 红里, 烛光, 花影, 锦地, 绣天, 珠星, 璧月, 人间, 别有]
# 21049     [送尽, 残春, 风前, 踪迹, 浅斟, 低唱, 月见, 西楼, 雨添, 南浦, 有人, 无计]
# 21050     [歙浦, 钱塘, 闲云, 如幕, 吴山, 应在, 无力, 海棠, 半眠, 官柳, 眼前, 春色]
# 21051     [宝髻, 双双, 妆光, 梅影, 收灯, 时候, 鱼子, 笺中, 龙香, 拨上, 明朝, 车马]
# 21052     [红锦, 障泥, 解鞍, 呼渡, 马骄, 不肯, 茅店, 竹篱, 绛裙, 青袂, 临平, 风物]
# Name: dic, Length: 21053, dtype: object

# %%
word_freq = dict()
dictionary = [item for sublist in poem_df['dic'] for item in sublist]
lyric_dictionary = [item for sublist in lyric_df['dic'] for item in sublist]
dictionary.extend(lyric_dictionary)
for i in dictionary:
    word_freq[i] = word_freq.get(i, 0) + 1

word_freq = {key:val for key, val in word_freq.items() if val >= 3}
    
with open('./lyric_dict.txt', 'w', encoding='utf-8') as f:
    for k, v in word_freq.items():
        f.write(f'{k} {v * 100}\n')

jieba.set_dictionary('./lyric_dict.txt')

# %%
def lyric_second_segment(lines):
    words = []
    for line in lines:
        if len(line) == 5:
            words.append(line[0:2])
            words.append(addition_segment(line[2:]))
        if len(line) == 7:
            words.append(line[0:2])
            words.append(line[2:4])
            words.append(addition_segment(line[4:]))
        else:
            tmp = jieba.lcut(line, cut_all=False)
            words.extend(list(filter(lambda x: len(x) >= 2, tmp)))
    return words

# %%
lyric_df['dic_total'] = lyric_df['lines'].apply(lyric_second_segment)
# Out:
# Building prefix dict from C:\Users\JUNHONG\history-digital\lyric_dict.txt ...
# Dumping model to file cache C:\Users\JUNHONG\AppData\Local\Temp\jieba.uaf15fae91440152dd276ee8f618272a6.cache
# Loading model cost 0.231 seconds.
# Prefix dict has been built successfully.

# %%
run_test_1()
# Out:
# Poem #1
# 秦川/雄/帝宅/，/函谷/壯/皇居/。
# 綺/殿/千尋/起/，/離宮/百雉/餘/。
# 連甍/遙接漢/，/飛觀/迥/凌虛/。
# 雲日/隱層/闕/，/風煙/出/綺疎/。
# Poem #2
# 遠山/媚/平楚/，/宿雨/漲/清溪/。
# 沿泝/任/舟檝/，/歡言/無/町畦/。
# 夜深/忽梦/少年/事/，/梦/啼妆/泪红/阑干
# Poem #3
# 剑外/忽/传收/蓟北/，/初闻/涕泪/满/衣裳/。
# 却看/妻子/愁/何在/，/漫卷/诗书/喜欲狂/。
# 白日/放歌/须/纵酒/，/青春/作伴/好/还/乡/。
# 即/从/巴峡/穿/巫峡/，/便下/襄阳/向/洛阳/。
# Poem #4
# 明月/几时/有/，/把酒/问/青天/。
# 不知/天上/宫阙/，/今夕/是何/年/。
# 我欲/乘风/归去/，/又恐/琼楼/玉宇/，/高处/不胜/寒/。
# 起舞/弄/清影/，/何似/在人/间/。
# 转/朱阁/，/低绮户/，/照/无眠/。
# 不应/有恨/，/何事/长向/别时/圆/。
# 人有/悲欢/离合/，/月有/阴晴/圆缺/，/此事/古难全/。
# 但愿/人长/久/，/千里/共/婵娟/。

# %% [markdown]
# 最后一次分词的结果。“却看/妻子/愁/何在”终于分对了，虽然“梦/啼妆/泪红/阑干”分错，但是我们只关心对后三个字的分词，所以无伤大雅。最关键的是，“转/朱阁”终于分出来了，“千里/共/婵娟”的“婵娟”也分出来了。但是上述几个分词词典都没正确地分出“但愿/人长/久”，我看字典里没有“长久”和“人长”，所以我认为是它随便分了。

# %% [markdown]
# 总结一下我的想法：
#
# 假设：五字句AABBB的前两个字AA，七字句AABBCCC的前四个字AA和BB，统一视为可以直接提取出来的“好意象”。当然这个规律也有例外，但是我只找到白居易的“家在虾蟆陵下住”这一个反例，我觉得只是因为白居易本来就专门写通俗化口语化的诗。后三个字的分法大相径庭，所以需要借助分词工具。
#
# 做法：
# 1. 先用唐诗和宋诗的“好意象”构建词典，然后用得到的词典对五字句AABBB的后三个字BBB，七字句AABBCCC的后三个字CCC分词。用对BBB和CCC的分词结果扩充词典。
# 2. 唐诗的分词完成。分词结果就是好意象+后三个字的分词。
# 3. 用宋词里的五字句的和七字句的“好意象”扩充词典，对宋词其他句式进行分词，
# 4. 宋词的分词完成。分词结果就是：
#         对于五字句和七字句：好意象+后三个字的分词；
#         对于其他句式：整句的分词结果

# %%
song_df = lyric_df

poems = []
file_list = os.listdir(POEM_DIR)
for file in file_list:
    if file.startswith('poet.tang'):
        poems.append(pd.read_json(f'{POEM_DIR}{file}'))
tang_df = pd.concat(poems, ignore_index=True)
tang_df['lines'] = tang_df['paragraphs'].apply(cut_lines)
jieba.set_dictionary('./poem_dict.txt')
tang_df['dic_total'] = tang_df['lines'].apply(second_segment)
jieba.set_dictionary('./lyric_dict.txt')
# Out:
# Building prefix dict from C:\Users\JUNHONG\history-digital\poem_dict.txt ...
# Loading model from cache C:\Users\JUNHONG\AppData\Local\Temp\jieba.u8c6200af4b343395bea15d660881757b.cache
# Loading model cost 0.151 seconds.
# Prefix dict has been built successfully.

# %% [markdown]
# 总之，目前可以使用tang_df['dic_total']和song_df['dic_total']来看唐诗和宋词的分词结果：

# %%
tang_df
# Out:
#       author                                         paragraphs     title  \
# 0       太宗皇帝  [秦川雄帝宅，函谷壯皇居。, 綺殿千尋起，離宮百雉餘。, 連甍遙接漢，飛觀迥凌虛。, 雲日隱...   帝京篇十首 一
# 1       太宗皇帝  [巖廊罷機務，崇文聊駐輦。, 玉匣啓龍圖，金繩披鳳篆。, 韋編斷仍續，縹帙舒還卷。, 對此乃...   帝京篇十首 二
# 2       太宗皇帝  [移步出詞林，停輿欣武宴。, 琱弓寫明月，駿馬疑流電。, 驚雁落虛弦，啼猿悲急箭。, 閱賞誠...   帝京篇十首 三
# 3       太宗皇帝  [鳴笳臨樂館，眺聽歡芳節。, 急管韻朱絃，清歌凝白雪。, 彩鳳肅來儀，玄鶴紛成列。, 去茲鄭...   帝京篇十首 四
# 4       太宗皇帝  [芳辰追逸趣，禁苑信多奇。, 橋形通漢上，峰勢接雲危。, 煙霞交隱映，花鳥自參差。, 何如肆...   帝京篇十首 五
# ...      ...                                                ...       ...
# 57607     梁鍠                       [莫向嵩山去，神仙多誤人。, 不如朝魏闕，天子重賢臣。]      贈李中華
# 57608     梁鍠               [刻木牽絲作老翁，雞皮鶴髮與真同。, 須臾弄罷寂無事，還似人生一夢中。]      詠木老人
# 57609     梁鍠                                     [堂高憑上望，宅廣乘車行。]         句
# 57610     杜儼               [書劒催人不暫閑，洛陽羈旅復秦關。, 容顏歲歲愁邊改，鄉國時時夢裏還。]       客中作
# 57611    趙良器  [聖祖發神謀，靈符叶帝求。, 一人光錫命，萬國荷時休。, 雷解圜丘畢，雲需曲水遊。, 岸花迎...  三月三日曲江侍宴
#
#                                          id tags  \
# 0      3ad6d468-7ff1-4a7b-8b24-a27d70d00ed4  NaN
# 1      13e72581-968b-457f-b381-a3b7d95b8b7c  NaN
# 2      a7ff247d-a11c-4ca9-a22f-ca420b8c537c  NaN
# 3      fa374b2b-c196-4362-b4ad-8931fc9a8860  NaN
# 4      86952cb3-b622-4398-a56a-01dd39f6c6ec  NaN
# ...                                     ...  ...
# 57607  bc3a22df-2cf8-43a7-971b-f0dd9b51e6d6  NaN
# 57608  8190cf76-f2af-400c-a09d-8877e9b25a62  NaN
# 57609  69b236e5-0a72-4f82-a581-7d8d83122f6c  NaN
# 57610  735c5425-745a-4a91-97e3-e6d262dce5fc  NaN
# 57611  b31f56ac-0f36-4a9b-9800-7db89789a1cf  NaN
#
#                                                    lines  \
# 0      [秦川雄帝宅, 函谷壯皇居, 綺殿千尋起, 離宮百雉餘, 連甍遙接漢, 飛觀迥凌虛, 雲日隱...
# 1      [巖廊罷機務, 崇文聊駐輦, 玉匣啓龍圖, 金繩披鳳篆, 韋編斷仍續, 縹帙舒還卷, 對此乃...
# 2      [移步出詞林, 停輿欣武宴, 琱弓寫明月, 駿馬疑流電, 驚雁落虛弦, 啼猿悲急箭, 閱賞誠...
# 3      [鳴笳臨樂館, 眺聽歡芳節, 急管韻朱絃, 清歌凝白雪, 彩鳳肅來儀, 玄鶴紛成列, 去茲鄭...
# 4      [芳辰追逸趣, 禁苑信多奇, 橋形通漢上, 峰勢接雲危, 煙霞交隱映, 花鳥自參差, 何如肆...
# ...                                                  ...
# 57607                       [莫向嵩山去, 神仙多誤人, 不如朝魏闕, 天子重賢臣]
# 57608               [刻木牽絲作老翁, 雞皮鶴髮與真同, 須臾弄罷寂無事, 還似人生一夢中]
# 57609                                     [堂高憑上望, 宅廣乘車行]
# 57610               [書劒催人不暫閑, 洛陽羈旅復秦關, 容顏歲歲愁邊改, 鄉國時時夢裏還]
# 57611  [聖祖發神謀, 靈符叶帝求, 一人光錫命, 萬國荷時休, 雷解圜丘畢, 雲需曲水遊, 岸花迎...
#
#                                                dic_total
# 0      [秦川, 帝宅, 函谷, 皇居, 綺殿, 千尋, 離宮, 百雉, 連甍, 遙接漢, 飛觀, ...
# 1      [巖廊, 機務, 崇文, 聊駐, 玉匣, 龍圖, 金繩, 鳳篆, 韋編, 仍續, 縹帙, 舒...
# 2      [移步, 詞林, 停輿, 欣武宴, 琱弓, 明月, 駿馬, 流電, 驚雁, 虛弦, 啼猿, ...
# 3      [鳴笳, 臨樂館, 眺聽, 芳節, 急管, 朱絃, 清歌, 凝白, 彩鳳, 來儀, 玄鶴, ...
# 4      [芳辰, 追逸趣, 禁苑, 多奇, 橋形, 漢上, 峰勢, 接雲危, 煙霞, 隱映, 花鳥,...
# ...                                                  ...
# 57607                   [莫向, 嵩山, 神仙, 多誤, 不如, 魏闕, 天子, 賢臣]
# 57608   [刻木, 牽絲, 老翁, 雞皮, 鶴髮, 真同, 須臾, 弄罷, 寂無, 還似, 人生, 一夢]
# 57609                                  [堂高, 憑上望, 宅廣, 乘車]
# 57610   [書劒, 催人, 暫閑, 洛陽, 羈旅, 秦關, 容顏, 歲歲, 愁邊, 鄉國, 時時, 夢裏]
# 57611  [聖祖, 神謀, 靈符, 帝求, 一人, 錫命, 萬國, 荷時, 雷解, 圜丘, 雲需, 曲...
#
# [57612 rows x 7 columns]

# %%
song_df
# Out:
#       author                                         paragraphs rhythmic tags  \
# 0         和岘  [气和玉烛，睿化著鸿明。, 缇管一阳生。, 郊禋盛礼燔柴毕，旋轸凤凰城。, 森罗仪卫振华缨。...       导引  NaN
# 1         和岘  [严夜警，铜莲漏迟迟。, 清禁肃，森陛戟，羽卫俨皇闱。, 角声励，钲鼓攸宜。, 金管成雅奏，...       六州  NaN
# 2         和岘  [承宝运，驯致隆平。, 鸿庆被寰瀛。, 时清俗阜，治定功成。, 遐迩咏由庚。, 严郊祀，文物...  十二时・忆少年  NaN
# 3         王禹  [雨恨云愁，江南依旧称佳丽。, 水村渔市。, 一缕孤烟细。, 天际征鸿，遥认行如缀。, 平生...      点绛唇  NaN
# 4        苏易简   [神仙神仙瑶池宴。, 片片。, 碧桃零落春风晚。, 翠云开处，隐隐金舆挽。, 玉麟背冷清风远。]      越江吟  NaN
# ...      ...                                                ...      ...  ...
# 21048    范成大  [催下珠帘护绮丛。, 花枝红里烛枝红。, 烛光花影夜葱茏。, 锦地绣天香雾里，珠星璧月彩云中...      浣溪沙  NaN
# 21049    范成大  [送尽残春更出游。, 风前踪迹似沙鸥。, 浅斟低唱小淹留。, 月见西楼清夜醉，雨添南浦绿波愁...      浣溪沙  NaN
# 21050    范成大  [歙浦钱塘一水通。, 闲云如幕碧重重。, 吴山应在碧云东。, 无力海棠风淡荡，半眠官柳日葱茏...      浣溪沙  NaN
# 21051    范成大  [宝髻双双出绮丛。, 妆光梅影各春风。, 收灯时候却相逢。, 鱼子笺中此宛转，龙香拨上语玲珑...      浣溪沙  NaN
# 21052    范成大  [红锦障泥杏叶鞯。, 解鞍呼渡忆当年。, 马骄不肯上航船。, 茅店竹篱开席市，绛裙青袂斸姜田...      浣溪沙  NaN
#
#       prologue                                              lines  \
# 0          NaN  [气和玉烛, 睿化著鸿明, 缇管一阳生, 郊禋盛礼燔柴毕, 旋轸凤凰城, 森罗仪卫振华缨, ...
# 1          NaN  [严夜警, 铜莲漏迟迟, 清禁肃, 森陛戟, 羽卫俨皇闱, 角声励, 钲鼓攸宜, 金管成雅奏...
# 2          NaN  [承宝运, 驯致隆平, 鸿庆被寰瀛, 时清俗阜, 治定功成, 遐迩咏由庚, 严郊祀, 文物声...
# 3          NaN  [雨恨云愁, 江南依旧称佳丽, 水村渔市, 一缕孤烟细, 天际征鸿, 遥认行如缀, 平生事,...
# 4          NaN       [神仙神仙瑶池宴, 片片, 碧桃零落春风晚, 翠云开处, 隐隐金舆挽, 玉麟背冷清风远]
# ...        ...                                                ...
# 21048      NaN  [催下珠帘护绮丛, 花枝红里烛枝红, 烛光花影夜葱茏, 锦地绣天香雾里, 珠星璧月彩云中, ...
# 21049      NaN  [送尽残春更出游, 风前踪迹似沙鸥, 浅斟低唱小淹留, 月见西楼清夜醉, 雨添南浦绿波愁, ...
# 21050      NaN  [歙浦钱塘一水通, 闲云如幕碧重重, 吴山应在碧云东, 无力海棠风淡荡, 半眠官柳日葱茏, ...
# 21051      NaN  [宝髻双双出绮丛, 妆光梅影各春风, 收灯时候却相逢, 鱼子笺中此宛转, 龙香拨上语玲珑, ...
# 21052      NaN  [红锦障泥杏叶鞯, 解鞍呼渡忆当年, 马骄不肯上航船, 茅店竹篱开席市, 绛裙青袂斸姜田, ...
#
#                                                      dic  \
# 0      [睿化, 缇管, 郊禋, 盛礼, 旋轸, 森罗, 仪卫, 载路, 皇图, 大业, 垂象, 九...
# 1                       [铜莲, 羽卫, 金管, 属景, 盛德, 三秀, 合尧, 蹈咏]
# 2      [鸿庆, 遐迩, 星拱, 布羽, 明德, 神降, 万乘, 肃銮, 玉帛, 皇泽, 普率, 睿...
# 3                                   [江南, 依旧, 一缕, 遥认, 谁会]
# 4                           [神仙, 神仙, 碧桃, 零落, 隐隐, 玉麟, 背冷]
# ...                                                  ...
# 21048   [催下, 珠帘, 花枝, 红里, 烛光, 花影, 锦地, 绣天, 珠星, 璧月, 人间, 别有]
# 21049   [送尽, 残春, 风前, 踪迹, 浅斟, 低唱, 月见, 西楼, 雨添, 南浦, 有人, 无计]
# 21050   [歙浦, 钱塘, 闲云, 如幕, 吴山, 应在, 无力, 海棠, 半眠, 官柳, 眼前, 春色]
# 21051   [宝髻, 双双, 妆光, 梅影, 收灯, 时候, 鱼子, 笺中, 龙香, 拨上, 明朝, 车马]
# 21052   [红锦, 障泥, 解鞍, 呼渡, 马骄, 不肯, 茅店, 竹篱, 绛裙, 青袂, 临平, 风物]
#
#                                                dic_total
# 0      [和玉, 睿化, 著鸿明, 睿化, 著鸿明, 缇管, 一阳, 一阳, 郊禋, 盛礼, 燔柴,...
# 1      [夜警, 铜莲, 迟迟, 铜莲漏, 迟迟, 清禁, 陛戟, 羽卫, 俨皇闱, 羽卫, 俨皇闱...
# 2      [承宝运, 驯致, 隆平, 鸿庆, 寰瀛, 鸿庆, 寰瀛, 时清, 俗阜, 治定, 功成, ...
# 3      [雨恨, 云愁, 江南, 依旧, 佳丽, 水村, 渔市, 一缕, 孤烟, 一缕, 孤烟, 天...
# 4      [神仙, 神仙, 瑶池, 片片, 碧桃, 零落, 春风, 翠云, 开处, 隐隐, 金舆, 隐...
# ...                                                  ...
# 21048  [催下, 珠帘, 护绮丛, 花枝, 红里, 烛枝, 烛光, 花影, 夜葱, 锦地, 绣天, ...
# 21049  [送尽, 残春, 更出, 风前, 踪迹, 沙鸥, 浅斟, 低唱, 小淹, 月见, 西楼, 清...
# 21050  [歙浦, 钱塘, 一水, 闲云, 如幕, 重重, 吴山, 应在, 碧云, 无力, 海棠, 淡...
# 21051  [宝髻, 双双, 出绮丛, 妆光, 梅影, 春风, 收灯, 时候, 相逢, 鱼子, 笺中, ...
# 21052  [红锦, 障泥, 杏叶, 解鞍, 呼渡, 忆当, 马骄, 不肯, 航船, 茅店, 竹篱, 开...
#
# [21053 rows x 8 columns]

# %%
tang_df.to_csv("tang_seg.csv")

# %%
song_df.to_csv("song_seg.csv")

# %%
libai = tang_df[tang_df['author']== '李白']
li_seg = libai['dic_total'].tolist()

# %%
li_seg[0]
# Out:
# ['三十',
#  '離宮',
#  '樓臺',
#  '與天',
#  '閣道',
#  '步行',
#  '美人',
#  '愁煙',
#  '恩疎',
#  '不及',
#  '桃李',
#  '傷春',
#  '淫樂',
#  '意何極',
#  '金輿',
#  '回中',
#  '萬乘',
#  '黃道',
#  '千旗',
#  '彩虹',
#  '前軍',
#  '細柳',
#  '後騎',
#  '甘泉',
#  '豈問',
#  '渭川',
#  '寧邀',
#  '野童',
#  '秋暮',
#  '瑤池',
#  '歸來',
#  '未窮']

# %%
import operator
from functools import reduce

li_list = reduce(operator.add, li_seg)
li_list
# Out:
# ['三十',
#  '離宮',
#  '樓臺',
#  '與天',
#  '閣道',
#  '步行',
#  '美人',
#  '愁煙',
#  '恩疎',
#  '不及',
#  '桃李',
#  '傷春',
#  '淫樂',
#  '意何極',
#  '金輿',
#  '回中',
#  '萬乘',
#  '黃道',
#  '千旗',
#  '彩虹',
#  '前軍',
#  '細柳',
#  '後騎',
#  '甘泉',
#  '豈問',
#  '渭川',
#  '寧邀',
#  '野童',
#  '秋暮',
#  '瑤池',
#  '歸來',
#  '未窮',
#  '洗兵',
#  '條支',
#  '海上',
#  '放馬',
#  '天山',
#  '雪中',
#  '萬里',
#  '長征',
#  '三軍',
#  '衰老',
#  '秦家',
#  '築城',
#  '備胡處',
#  '漢家',
#  '還有',
#  '烽火',
#  '烽火',
#  '不息',
#  '征戰',
#  '無已',
#  '野戰',
#  '格鬬',
#  '敗馬',
#  '號鳴',
#  '向天',
#  '烏鳶',
#  '人腸',
#  '銜飛',
#  '上挂',
#  '枯樹',
#  '士卒',
#  '草莽',
#  '將軍',
#  '空爾',
#  '乃知',
#  '兵者',
#  '凶器',
#  '奔流',
#  '到海',
#  '不復',
#  '朝如',
#  '青絲',
#  '成雪',
#  '人生',
#  '得意',
#  '須盡',
#  '莫使',
#  '金尊',
#  '空對',
#  '天生',
#  '我材',
#  '必有',
#  '千金',
#  '散盡',
#  '還復',
#  '烹羊',
#  '宰牛',
#  '且爲',
#  '會須',
#  '一飲',
#  '三百',
#  '與君',
#  '一曲',
#  '請君',
#  '爲我',
#  '側耳',
#  '鐘鼓',
#  '饌玉',
#  '不足',
#  '但願',
#  '長醉',
#  '不復',
#  '古來',
#  '聖賢',
#  '寂寞',
#  '惟有',
#  '飲者',
#  '其名',
#  '陳王',
#  '昔時',
#  '平樂',
#  '斗酒',
#  '十千',
#  '恣歡',
#  '主人',
#  '何爲',
#  '言少',
#  '徑須',
#  '酤取',
#  '對君',
#  '呼兒',
#  '將出',
#  '美酒',
#  '與爾',
#  '同銷',
#  '萬古',
#  '馬色',
#  '雖不',
#  '人心',
#  '本無',
#  '共作',
#  '遊冶',
#  '雙行',
#  '洛陽',
#  '長劒',
#  '照曜',
#  '高冠',
#  '何赩赫',
#  '各有',
#  '千金',
#  '俱爲',
#  '五侯',
#  '猛虎',
#  '陷穽',
#  '壯夫',
#  '時屈',
#  '相知',
#  '急難',
#  '獨好',
#  '亦何',
#  '乃在',
#  '碧海',
#  '之東',
#  '海寒',
#  '天風',
#  '白波',
#  '連山',
#  '蓬壺',
#  '長鯨',
#  '噴湧',
#  '不可',
#  '撫心',
#  '茫茫',
#  '淚如',
#  '西來',
#  '青鳥',
#  '東飛',
#  '願寄',
#  '一書',
#  '麻姑',
#  '辟邪',
#  '伎作',
#  '鼓吹',
#  '雉子',
#  '班之',
#  '奏曲',
#  '喔咿',
#  '振迅',
#  '欲飛',
#  '雙雌',
#  '同飲',
#  '趫悍',
#  '誰能',
#  '乍向',
#  '草中',
#  '耿介',
#  '不求',
#  '黃金',
#  '下生',
#  '天地',
#  '廣大',
#  '何惜',
#  '物情',
#  '善卷',
#  '天子',
#  '務光',
#  '逃名',
#  '所貴',
#  '曠士',
#  '朗然',
#  '太清',
#  '垂楊',
#  '綠水',
#  '搖豔',
#  '東風',
#  '花明',
#  '玉關',
#  '葉暖',
#  '金窗',
#  '美人',
#  '長恨',
#  '相對',
#  '悽然',
#  '攀條',
#  '春色',
#  '遠寄',
#  '龍庭',
#  '明月',
#  '天山',
#  '蒼茫',
#  '雲海',
#  '長風',
#  '幾萬',
#  '吹度',
#  '玉門',
#  '漢下',
#  '白登',
#  '胡窺',
#  '青海',
#  '由來',
#  '征戰',
#  '不見',
#  '有人',
#  '戍客',
#  '邊色',
#  '思歸',
#  '多苦顏',
#  '高樓',
#  '當此',
#  '歎息',
#  '未應',
#  '白玉',
#  '誰家',
#  '回車',
#  '天津',
#  '看花',
#  '東上',
#  '驚動',
#  '洛陽',
#  '紫騮',
#  '行且',
#  '雙飜',
#  '碧玉',
#  '臨流',
#  '不肎渡',
#  '似惜',
#  '錦障',
#  '白雪',
#  '關山',
#  '黃雲',
#  '海樹',
#  '揮鞭',
#  '萬里',
#  '安得',
#  '春閨',
#  '幽州',
#  '胡馬',
#  '綠眼',
#  '虎皮',
#  '笑拂',
#  '兩隻',
#  '萬人',
#  '不可',
#  '彎弓',
#  '若轉',
#  '白雁',
#  '雲端',
#  '雙雙',
#  '掉鞭',
#  '遊獵',
#  '樓蘭',
#  '出門',
#  '不顧',
#  '報國',
#  '何難',
#  '天驕',
#  '單于',
#  '狼戾',
#  '凶殘',
#  '牛馬',
#  '北海',
#  '割鮮',
#  '若虎餐',
#  '雖居',
#  '燕支',
#  '不道',
#  '朔雪',
#  '婦女',
#  '馬上',
#  '顏如',
#  '赬玉',
#  '飜入',
#  '鳥獸',
#  '花月',
#  '雕鞍',
#  '旄頭',
#  '光芒',
#  '爭戰',
#  '若蜂',
#  '白刃',
#  '赤血',
#  '流沙',
#  '爲之',
#  '名將',
#  '誰是',
#  '疲兵',
#  '可歎',
#  '銀鞍',
#  '白鼻',
#  '綠地',
#  '障泥',
#  '細雨',
#  '春風',
#  '花落',
#  '揮鞭',
#  '且就',
#  '胡姬',
#  '黃河',
#  '西來',
#  '崐崘',
#  '咆吼',
#  '萬里',
#  '龍門',
#  '大禹',
#  '百川',
#  '兒啼',
#  '不窺',
#  '殺湍',
#  '洪水',
#  '九州',
#  '始蠶麻',
#  '被髮',
#  '之叟',
#  '狂而癡',
#  '清晨',
#  '徑流',
#  '奚爲',
#  '旁人',
#  '不惜',
#  '止之',
#  '公無',
#  '渡河',
#  '苦渡',
#  '公果',
#  '溺死',
#  '流海湄',
#  '挂骨',
#  '於其',
#  '箜篌',
#  '所悲',
#  '竟不',
#  '登高',
#  '丘而',
#  '望遠',
#  '六鼇',
#  '骨已',
#  '三山',
#  '安在',
#  '扶桑',
#  '半摧',
#  '白日',
#  '光彩',
#  '銀臺',
#  '金闕',
#  '如夢',
#  '秦皇',
#  '漢武',
#  '相待',
#  '精衛',
#  '木石',
#  '黿鼉',
#  '無所',
#  '牧羊',
#  '之子',
#  '攀登',
#  '盜賊',
#  '寶玉',
#  '精靈',
#  '何能',
#  '松子',
#  '金華',
#  '安期',
#  '蓬海',
#  '此人',
#  '古之',
#  '倏忽',
#  '光彩',
#  '天地',
#  '凋換',
#  '容顏',
#  '有遷',
#  '對酒',
#  '不肯',
#  '含情',
#  '欲誰待',
#  '勸君',
#  '拒杯',
#  '春風',
#  '笑人',
#  '桃李',
#  '如舊',
#  '傾花',
#  '向我',
#  '流鶯',
#  '碧樹',
#  '明月',
#  '金罍',
#  '昨來',
#  '朱顏',
#  '今日',
#  '白髮',
#  '棘生',
#  '石虎',
#  '鹿走',
#  '姑蘇',
#  '自古',
#  '帝王',
#  '城闕',
#  '黃埃',
#  '君若',
#  '不飲',
#  '昔人',
#  '安在',
#  '美女',
#  '渭橋',
#  '春還',
#  '事蠶作',
#  '五馬',
#  '如飛',
#  '青絲',
#  '金絡',
#  '不知',
#  '誰家',
#  '調笑',
#  '相謔',
#  '妾本',
#  '羅敷',
#  '玉顏',
#  '名都',
#  '綠條',
#  '素手',
#  '采桑',
#  '向城',
#  '使君',
#  '且不',
#  '況復',
#  '秋胡',
#  '寒螿',
#  '碧草',
#  '鳴鳳',
#  '青梧',
#  '託心',
#  '自有',
#  '但怪',
#  '傍人',
#  '徒令',
#  '白日',
#  '高駕',
#  '踟躕',
#  '日出',
#  '東方',
#  '似從',
#  '地底',
#  '歷天',
#  '又入',
#  '草不',
#  '謝榮',
#  '於春',
#  '木不',
#  '怨落',
#  '於秋',
#  '誰揮',
#  '鞭策',
#  '四運',
#  '萬物',
#  '興歇',
#  '皆自',
#  '浩然',
#  '與溟',
#  '同科',
#  '漢家',
#  '秦地',
#  '流影',
#  '明妃',
#  '一上',
#  '玉關',
#  '天涯',
#  '去不',
#  '漢月',
#  '還從',
#  '東海',
#  '明妃',
#  '西嫁',
#  '無來',
#  '燕支',
#  '長寒',
#  '雪作',
#  '蛾眉',
#  '顦顇',
#  '胡沙',
#  '生乏',
#  '黃金',
#  '圖畫',
#  '死留',
#  '青冢',
#  '使人',
#  '昭君',
#  '玉鞍',
#  '上馬',
#  '啼紅',
#  '今日',
#  '漢宮',
#  '明朝',
#  '胡地',
#  '桃李',
#  '日開',
#  '榮華',
#  '當年',
#  '東風',
#  '百物',
#  '草木',
#  '盡欲',
#  '枯枝',
#  '無醜',
#  '涸水',
#  '清泉',
#  '大力',
#  '天地',
#  '羲和',
#  '無停',
#  '功名',
#  '不早',
#  '誰能',
#  '白日',
#  '富貴',
#  '神仙',
#  '蹉跎',
#  '兩失',
#  '金石',
#  '銷鑠',
#  '風霜',
#  '無久',
#  '畏落',
#  '日月',
#  '強歡',
#  '與酒',
#  '秋霜',
#  '不惜',
#  '倏忽',
#  '蒲柳',
#  '白日',
#  '短短',
#  '百年',
#  '易滿',
#  '蒼穹',
#  '茫茫',
#  '萬劫',
#  '太極',
#  '麻姑',
#  '兩鬢',
#  '一半',
#  '已成',
#  '天公',
#  '玉女',
#  '大笑',
#  '千場',
#  '吾欲',
#  '六龍',
#  '回車',
#  '扶桑',
#  '北斗',
#  '美酒',
#  '勸龍',
#  '各一',
#  '富貴',
#  '非所',
#  '爲人',
#  '頹光',
#  '朝作',
#  '猛虎',
#  '暮作',
#  '猛虎',
#  '腸斷',
#  '非關',
#  '隴頭',
#  '淚下',
#  '不爲',
#  '雍門',
#  '旌旗',
#  '繽紛',
#  '兩河',
#  '戰鼓',
#  '驚山',
#  '欲傾',
#  '秦人',
#  '半作',
#  '燕地',
#  '胡馬',
#  '飜銜',
#  '洛陽',
#  '一輸',
#  '一失',
#  '關下',
#  '朝降',
#  '夕叛',
#  '幽薊',
#  '巨鼇',
#  '未斬',
#  '海水',
#  '魚龍',
#  '奔走',
#  '安得',
#  '頗似',
#  '楚漢',
#  '飜覆',
#  '無定',
#  '朝過',
#  '博浪',
#  '暮入',
#  '淮陰',
#  '張良',
#  '未遇',
#  '韓信',
#  '劉項',
#  '存亡',
#  '兩臣',
#  '暫到',
#  '下邳',
#  '受兵略',
#  '來投',
#  '漂母',
#  '作主',
#  '賢哲',
#  '栖栖',
#  '如此',
#  '今時',
#  '亦棄',
#  '青雲',
#  '有策',
#  '不敢',
#  '龍鱗',
#  '竄身',
#  '南國',
#  '避胡',
#  '寶書',
#  '長劒',
#  '高閣',
#  '金鞍',
#  '駿馬',
#  '故人',
#  '昨日',
#  '方爲',
#  '宣城',
#  '掣鈴',
#  '交通',
#  '二千',
#  '有時',
#  '六博',
#  '壯心',
#  '繞牀',
#  '三帀',
#  '一擲',
#  '楚人',
#  '每道',
#  '張旭',
#  '心藏',
#  '風雲',
#  '世莫',
#  '三吳',
#  '邦伯',
#  '顧盼',
#  '四海',
#  '雄俠',
#  '相推',
#  '蕭曹',
#  '曾作',
#  '沛中',
#  '攀龍',
#  '附鳳',
#  '當有',
#  '溧陽',
#  '酒樓',
#  '三月',
#  '楊花',
#  '漠漠',
#  '愁殺',
#  '胡人',
#  '綠眼',
#  '吹玉',
#  '吳歌',
#  '白紵',
#  '飛梁',
#  '丈夫',
#  '相見',
#  '且爲',
#  '槌牛',
#  '撾鼓',
#  '衆賓',
#  '我從',
#  '此去',
#  '東海',
#  '得魚',
#  '笑寄',
#  '相親',
#  '從軍',
#  '玉門',
#  '逐虜',
#  '金微',
#  '笛奏',
#  '梅花',
#  '刀開',
#  '明月',
#  '鼓聲',
#  '海上',
#  '兵氣',
#  '擁雲',
#  '願斬',
#  '單于',
#  '長驅',
#  '鐵關',
#  '百戰',
#  '沙場',
#  '鐵衣',
#  '城南',
#  '已合',
#  '數重',
#  '突營',
#  '射殺',
#  '呼延將',
#  '獨領',
#  '殘兵',
#  '千騎',
#  '玉不',
#  '自言',
#  '桃李',
#  '魚目',
#  '笑之',
#  '卞和',
#  '荆山',
#  '長號',
#  '泣血',
#  '忠臣',
#  '死爲',
#  '刖足',
#  '聽曲',
#  '甯戚',
#  '秦穆',
#  '五羊',
#  '買死',
#  '百里',
#  '洗拂',
#  '青雲',
#  '當時',
#  '如泥',
#  '朝歌',
#  '鼓刀',
#  '虎變',
#  '蟠溪',
#  '一舉',
#  '六合',
#  '逐荒',
#  '營丘',
#  '平生',
#  '渭水',
#  '誰識',
#  '此老',
#  '奈何',
#  '今之',
#  '雙目',
#  '征鴻',
#  '北上',
#  '何所',
#  '北上',
#  '太行',
#  '磴道',
#  '盤且',
#  '巉巖',
#  '穹蒼',
#  '馬足',
#  '側石',
#  '車輪',
#  '高岡',
#  '沙塵',
#  '幽州',
#  '烽火',
#  '朔方',
#  '殺氣',
#  '劒戟',
#  '嚴風',
#  '裂衣',
#  '奔鯨',
#  '黃河',
#  '鑿齒',
#  '洛陽',
#  '前行',
#  '無歸',
#  '返顧',
#  '思舊',
#  '慘戚',
#  '冰雪',
#  '悲號',
#  '中腸',
#  '尺布',
#  '不掩',
#  '皮膚',
#  '枯桑',
#  '汲水',
#  '澗谷',
#  '采薪',
#  '隴坂',
#  '猛虎',
#  '掉尾',
#  '磨牙',
#  '秋霜',
#  '草木',
#  '不可',
#  '飢飲',
#  '零露',
#  '歎此',
#  '北上',
#  '停驂',
#  '爲之',
#  '胡風',
#  '代馬',
#  '北擁',
#  '魯陽',
#  '吳兵',
#  '照海',
#  '黃雲',
#  '無顏',
#  '老母',
#  '與子',
#  '呼天',
#  '野草',
#  '白馬',
#  '旌旗',
#  '悲鳴',
#  '相追',
#  '白楊',
#  '秋月',
#  '早落',
#  '豫章',
#  '本爲',
#  '休明',
#  '斬虜',
#  '素不',
#  '豈惜',
#  '戰鬬',
#  '爲君',
#  '埽兇頑',
#  '精感',
#  '沒羽',
#  '豈忘',
#  '險艱',
#  '樓船',
#  '若鯨飛',
#  '波蕩',
#  '落星',
#  '此曲',
#  '不可',
#  '三軍',
#  '鬢成',
#  '朝騎',
#  '五花',
#  '謁帝',
#  '銀臺',
#  '秀色',
#  '誰家',
#  '雲車',
#  '珠箔',
#  '金鞭',
#  '遙指',
#  '玉勒',
#  '遲回',
#  '夾轂',
#  '借問',
#  '疑從',
#  '天上',
#  '憐腸',
#  '欲斷',
#  '斜日',
#  '相催',
#  '下車',
#  '輕盈',
#  '飄然',
#  '落梅',
#  '邀入',
#  '青綺',
#  '當歌',
#  '銜杯',
#  '銜杯',
#  '歌扇',
#  '似月',
#  '雲中',
#  '相見',
#  '不相',
#  '不如',
#  '不相',
#  '相見',
#  '已深',
#  '未語',
#  '可知',
#  '胡爲',
#  '空閨',
#  '孤眠',
#  '錦衾',
#  '錦衾',
#  '羅幃',
#  '纏緜',
#  '會有',
#  '春風',
#  '澹蕩',
#  '更報',
#  '長相',
#  '光景',
#  '不待',
#  '須臾',
#  '成絲',
#  '當年',
#  '行樂',
#  '老去',
#  '徒傷',
#  '持此',
#  '密意',
#  '無令',
#  '佳期',
#  '相逢',
#  '紅塵',
#  '高揖',
#  '黃金',
#  '萬戶',
#  '垂楊',
#  '君家',
#  '阿那',
#  '乘龍',
#  '三天',
#  '飛目',
#  '兩角',
#  '行至',
#  '留田',
#  '孤墳',
#  '崢嶸',
#  '積此',
#  '萬古',
#  '春草',
#  '不復',
#  '悲風',
#  '四邊',
#  '腸斷',
#  '白楊',
#  '借問',
#  '誰家',
#  '埋沒',
#  '蒿里',
#  '古老',
#  '向余',
#  '言是',
#  '留田',
#  '蓬科',
#  '馬鬣',
#  '今已',
#  '昔之',
#  '弟死',
#  '不葬',
#  '他人',
#  '於此',
#  '銘旌',
#  '桓山',
#  '之禽',
#  '別離',
#  '欲去',
#  '迴翔',
#  '不能',
#  '田氏',
#  '倉卒',
#  '骨肉',
#  '青天',
#  '白日',
#  '紫荆',
#  '交柯',
#  '之木',
#  '本同',
#  '東枝',
#  '顦顇',
#  '西枝',
#  '無心',
#  '之物',
#  '尚如',
#  ...]

# %%
from collections import Counter

result_li = Counter(li_list)

# %%
result_li
# Out:
# Counter({'三十': 19,
#          '離宮': 3,
#          '樓臺': 5,
#          '與天': 9,
#          '閣道': 3,
#          '步行': 2,
#          '美人': 28,
#          '愁煙': 1,
#          '恩疎': 4,
#          '不及': 13,
#          '桃李': 42,
#          '傷春': 2,
#          '淫樂': 3,
#          '意何極': 2,
#          '金輿': 3,
#          '回中': 3,
#          '萬乘': 16,
#          '黃道': 2,
#          '千旗': 2,
#          '彩虹': 5,
#          '前軍': 2,
#          '細柳': 4,
#          '後騎': 2,
#          '甘泉': 5,
#          '豈問': 2,
#          '渭川': 4,
#          '寧邀': 2,
#          '野童': 2,
#          '秋暮': 1,
#          '瑤池': 7,
#          '歸來': 26,
#          '未窮': 5,
#          '洗兵': 2,
#          '條支': 2,
#          '海上': 21,
#          '放馬': 2,
#          '天山': 8,
#          '雪中': 4,
#          '萬里': 60,
#          '長征': 2,
#          '三軍': 11,
#          '衰老': 5,
#          '秦家': 5,
#          '築城': 2,
#          '備胡處': 1,
#          '漢家': 13,
#          '還有': 4,
#          '烽火': 10,
#          '不息': 4,
#          '征戰': 8,
#          '無已': 2,
#          '野戰': 2,
#          '格鬬': 2,
#          '敗馬': 2,
#          '號鳴': 2,
#          '向天': 9,
#          '烏鳶': 4,
#          '人腸': 4,
#          '銜飛': 2,
#          '上挂': 2,
#          '枯樹': 2,
#          '士卒': 2,
#          '草莽': 2,
#          '將軍': 14,
#          '空爾': 3,
#          '乃知': 6,
#          '兵者': 2,
#          '凶器': 2,
#          '奔流': 2,
#          '到海': 2,
#          '不復': 10,
#          '朝如': 2,
#          '青絲': 7,
#          '成雪': 2,
#          '人生': 15,
#          '得意': 6,
#          '須盡': 2,
#          '莫使': 5,
#          '金尊': 4,
#          '空對': 2,
#          '天生': 3,
#          '我材': 2,
#          '必有': 2,
#          '千金': 20,
#          '散盡': 5,
#          '還復': 3,
#          '烹羊': 2,
#          '宰牛': 2,
#          '且爲': 6,
#          '會須': 2,
#          '一飲': 2,
#          '三百': 14,
#          '與君': 28,
#          '一曲': 5,
#          '請君': 4,
#          '爲我': 16,
#          '側耳': 2,
#          '鐘鼓': 3,
#          '饌玉': 2,
#          '不足': 17,
#          '但願': 4,
#          '長醉': 3,
#          '古來': 13,
#          '聖賢': 3,
#          '寂寞': 8,
#          '惟有': 10,
#          '飲者': 2,
#          '其名': 3,
#          '陳王': 3,
#          '昔時': 5,
#          '平樂': 2,
#          '斗酒': 10,
#          '十千': 6,
#          '恣歡': 1,
#          '主人': 17,
#          '何爲': 5,
#          '言少': 2,
#          '徑須': 3,
#          '酤取': 1,
#          '對君': 5,
#          '呼兒': 6,
#          '將出': 2,
#          '美酒': 27,
#          '與爾': 10,
#          '同銷': 2,
#          '萬古': 30,
#          '馬色': 2,
#          '雖不': 5,
#          '人心': 6,
#          '本無': 10,
#          '共作': 2,
#          '遊冶': 4,
#          '雙行': 4,
#          '洛陽': 27,
#          '長劒': 11,
#          '照曜': 2,
#          '高冠': 3,
#          '何赩赫': 2,
#          '各有': 4,
#          '俱爲': 3,
#          '五侯': 4,
#          '猛虎': 18,
#          '陷穽': 2,
#          '壯夫': 5,
#          '時屈': 2,
#          '相知': 7,
#          '急難': 3,
#          '獨好': 2,
#          '亦何': 10,
#          '乃在': 4,
#          '碧海': 6,
#          '之東': 2,
#          '海寒': 2,
#          '天風': 8,
#          '白波': 7,
#          '連山': 10,
#          '蓬壺': 9,
#          '長鯨': 12,
#          '噴湧': 2,
#          '不可': 75,
#          '撫心': 2,
#          '茫茫': 22,
#          '淚如': 14,
#          '西來': 14,
#          '青鳥': 6,
#          '東飛': 4,
#          '願寄': 2,
#          '一書': 6,
#          '麻姑': 9,
#          '辟邪': 2,
#          '伎作': 2,
#          '鼓吹': 3,
#          '雉子': 4,
#          '班之': 2,
#          '奏曲': 3,
#          '喔咿': 2,
#          '振迅': 2,
#          '欲飛': 4,
#          '雙雌': 2,
#          '同飲': 2,
#          '趫悍': 2,
#          '誰能': 13,
#          '乍向': 2,
#          '草中': 2,
#          '耿介': 2,
#          '不求': 3,
#          '黃金': 68,
#          '下生': 2,
#          '天地': 47,
#          '廣大': 2,
#          '何惜': 5,
#          '物情': 4,
#          '善卷': 2,
#          '天子': 27,
#          '務光': 2,
#          '逃名': 3,
#          '所貴': 3,
#          '曠士': 2,
#          '朗然': 3,
#          '太清': 11,
#          '垂楊': 8,
#          '綠水': 25,
#          '搖豔': 3,
#          '東風': 20,
#          '花明': 3,
#          '玉關': 14,
#          '葉暖': 2,
#          '金窗': 5,
#          '長恨': 1,
#          '相對': 3,
#          '悽然': 2,
#          '攀條': 3,
#          '春色': 8,
#          '遠寄': 5,
#          '龍庭': 3,
#          '明月': 52,
#          '蒼茫': 6,
#          '雲海': 6,
#          '長風': 20,
#          '幾萬': 4,
#          '吹度': 2,
#          '玉門': 4,
#          '漢下': 2,
#          '白登': 3,
#          '胡窺': 2,
#          '青海': 3,
#          '由來': 12,
#          '不見': 32,
#          '有人': 5,
#          '戍客': 1,
#          '邊色': 2,
#          '思歸': 12,
#          '多苦顏': 3,
#          '高樓': 12,
#          '當此': 3,
#          '歎息': 11,
#          '未應': 5,
#          '白玉': 27,
#          '誰家': 19,
#          '回車': 3,
#          '天津': 6,
#          '看花': 5,
#          '東上': 2,
#          '驚動': 2,
#          '紫騮': 5,
#          '行且': 3,
#          '雙飜': 1,
#          '碧玉': 5,
#          '臨流': 2,
#          '不肎渡': 1,
#          '似惜': 2,
#          '錦障': 2,
#          '白雪': 20,
#          '關山': 7,
#          '黃雲': 12,
#          '海樹': 4,
#          '揮鞭': 5,
#          '安得': 24,
#          '春閨': 2,
#          '幽州': 7,
#          '胡馬': 15,
#          '綠眼': 4,
#          '虎皮': 2,
#          '笑拂': 2,
#          '兩隻': 2,
#          '萬人': 9,
#          '彎弓': 8,
#          '若轉': 3,
#          '白雁': 4,
#          '雲端': 3,
#          '雙雙': 6,
#          '掉鞭': 2,
#          '遊獵': 4,
#          '樓蘭': 5,
#          '出門': 10,
#          '不顧': 5,
#          '報國': 5,
#          '何難': 2,
#          '天驕': 5,
#          '單于': 7,
#          '狼戾': 2,
#          '凶殘': 1,
#          '牛馬': 3,
#          '北海': 9,
#          '割鮮': 2,
#          '若虎餐': 2,
#          '雖居': 2,
#          '燕支': 7,
#          '不道': 5,
#          '朔雪': 7,
#          '婦女': 3,
#          '馬上': 3,
#          '顏如': 7,
#          '赬玉': 2,
#          '飜入': 1,
#          '鳥獸': 2,
#          '花月': 7,
#          '雕鞍': 4,
#          '旄頭': 5,
#          '光芒': 2,
#          '爭戰': 3,
#          '若蜂': 2,
#          '白刃': 6,
#          '赤血': 5,
#          '流沙': 4,
#          '爲之': 12,
#          '名將': 2,
#          '誰是': 2,
#          '疲兵': 2,
#          '可歎': 4,
#          '銀鞍': 10,
#          '白鼻': 2,
#          '綠地': 2,
#          '障泥': 2,
#          '細雨': 2,
#          '春風': 65,
#          '花落': 9,
#          '且就': 2,
#          '胡姬': 7,
#          '黃河': 25,
#          '崐崘': 1,
#          '咆吼': 1,
#          '龍門': 7,
#          '大禹': 2,
#          '百川': 12,
#          '兒啼': 2,
#          '不窺': 3,
#          '殺湍': 2,
#          '洪水': 2,
#          '九州': 6,
#          '始蠶麻': 2,
#          '被髮': 2,
#          '之叟': 2,
#          '狂而癡': 2,
#          '清晨': 10,
#          '徑流': 1,
#          '奚爲': 2,
#          '旁人': 3,
#          '不惜': 11,
#          '止之': 2,
#          '公無': 3,
#          '渡河': 4,
#          '苦渡': 2,
#          '公果': 2,
#          '溺死': 2,
#          '流海湄': 2,
#          '挂骨': 1,
#          '於其': 1,
#          '箜篌': 2,
#          '所悲': 2,
#          '竟不': 17,
#          '登高': 20,
#          '丘而': 1,
#          '望遠': 6,
#          '六鼇': 2,
#          '骨已': 2,
#          '三山': 14,
#          '安在': 10,
#          '扶桑': 8,
#          '半摧': 2,
#          '白日': 57,
#          '光彩': 9,
#          '銀臺': 10,
#          '金闕': 8,
#          '如夢': 5,
#          '秦皇': 4,
#          '漢武': 4,
#          '相待': 5,
#          '精衛': 4,
#          '木石': 2,
#          '黿鼉': 2,
#          '無所': 10,
#          '牧羊': 4,
#          '之子': 3,
#          '攀登': 2,
#          '盜賊': 2,
#          '寶玉': 2,
#          '精靈': 3,
#          '何能': 4,
#          '松子': 3,
#          '金華': 7,
#          '安期': 6,
#          '蓬海': 6,
#          '此人': 5,
#          '古之': 4,
#          '倏忽': 9,
#          '凋換': 2,
#          '容顏': 5,
#          '有遷': 2,
#          '對酒': 13,
#          '不肯': 13,
#          '含情': 5,
#          '欲誰待': 2,
#          '勸君': 3,
#          '拒杯': 2,
#          '笑人': 3,
#          '如舊': 4,
#          '傾花': 2,
#          '向我': 5,
#          '流鶯': 5,
#          '碧樹': 6,
#          '金罍': 5,
#          '昨來': 2,
#          '朱顏': 16,
#          '今日': 25,
#          '白髮': 18,
#          '棘生': 2,
#          '石虎': 2,
#          '鹿走': 2,
#          '姑蘇': 8,
#          '自古': 10,
#          '帝王': 12,
#          '城闕': 2,
#          '黃埃': 2,
#          '君若': 1,
#          '不飲': 2,
#          '昔人': 2,
#          '美女': 6,
#          '渭橋': 6,
#          '春還': 4,
#          '事蠶作': 2,
#          '五馬': 9,
#          '如飛': 3,
#          '金絡': 3,
#          '不知': 33,
#          '調笑': 5,
#          '相謔': 2,
#          '妾本': 5,
#          '羅敷': 4,
#          '玉顏': 12,
#          '名都': 3,
#          '綠條': 2,
#          '素手': 13,
#          '采桑': 2,
#          '向城': 2,
#          '使君': 6,
#          '且不': 4,
#          '況復': 2,
#          '秋胡': 5,
#          '寒螿': 2,
#          '碧草': 8,
#          '鳴鳳': 4,
#          '青梧': 3,
#          '託心': 2,
#          '自有': 10,
#          '但怪': 3,
#          '傍人': 3,
#          '徒令': 3,
#          '高駕': 4,
#          '踟躕': 5,
#          '日出': 9,
#          '東方': 8,
#          '似從': 2,
#          '地底': 4,
#          '歷天': 3,
#          '又入': 2,
#          '草不': 2,
#          '謝榮': 2,
#          '於春': 2,
#          '木不': 2,
#          '怨落': 2,
#          '於秋': 2,
#          '誰揮': 2,
#          '鞭策': 4,
#          '四運': 2,
#          '萬物': 6,
#          '興歇': 2,
#          '皆自': 2,
#          '浩然': 4,
#          '與溟': 2,
#          '同科': 2,
#          '秦地': 9,
#          '流影': 2,
#          '明妃': 6,
#          '一上': 2,
#          '天涯': 14,
#          '去不': 5,
#          '漢月': 2,
#          '還從': 3,
#          '東海': 20,
#          '西嫁': 2,
#          '無來': 2,
#          '長寒': 2,
#          '雪作': 2,
#          '蛾眉': 19,
#          '顦顇': 6,
#          '胡沙': 11,
#          '生乏': 2,
#          '圖畫': 2,
#          '死留': 2,
#          '青冢': 2,
#          '使人': 17,
#          '昭君': 2,
#          '玉鞍': 2,
#          '上馬': 5,
#          '啼紅': 2,
#          '漢宮': 10,
#          '明朝': 13,
#          '胡地': 4,
#          '日開': 2,
#          '榮華': 3,
#          '當年': 9,
#          '百物': 2,
#          '草木': 17,
#          '盡欲': 2,
#          '枯枝': 4,
#          '無醜': 2,
#          '涸水': 2,
#          '清泉': 3,
#          '大力': 2,
#          '羲和': 3,
#          '無停': 3,
#          '功名': 7,
#          '不早': 2,
#          '富貴': 15,
#          '神仙': 11,
#          '蹉跎': 13,
#          '兩失': 2,
#          '金石': 4,
#          '銷鑠': 3,
#          '風霜': 3,
#          '無久': 2,
#          '畏落': 2,
#          '日月': 20,
#          '強歡': 1,
#          '與酒': 2,
#          '秋霜': 15,
#          '蒲柳': 3,
#          '短短': 2,
#          '百年': 11,
#          '易滿': 2,
#          '蒼穹': 4,
#          '萬劫': 2,
#          '太極': 2,
#          '兩鬢': 6,
#          '一半': 3,
#          '已成': 6,
#          '天公': 2,
#          '玉女': 13,
#          '大笑': 8,
#          '千場': 2,
#          '吾欲': 4,
#          '六龍': 8,
#          '北斗': 10,
#          '勸龍': 2,
#          '各一': 3,
#          '非所': 2,
#          '爲人': 6,
#          '頹光': 2,
#          '朝作': 2,
#          '暮作': 2,
#          '腸斷': 21,
#          '非關': 2,
#          '隴頭': 5,
#          '淚下': 5,
#          '不爲': 9,
#          '雍門': 2,
#          '旌旗': 10,
#          '繽紛': 3,
#          '兩河': 3,
#          '戰鼓': 3,
#          '驚山': 2,
#          '欲傾': 2,
#          '秦人': 8,
#          '半作': 2,
#          '燕地': 2,
#          '飜銜': 1,
#          '一輸': 2,
#          '一失': 2,
#          '關下': 2,
#          '朝降': 2,
#          '夕叛': 2,
#          '幽薊': 2,
#          '巨鼇': 6,
#          '未斬': 2,
#          '海水': 16,
#          '魚龍': 3,
#          '奔走': 3,
#          '頗似': 7,
#          '楚漢': 7,
#          '飜覆': 4,
#          '無定': 6,
#          '朝過': 2,
#          '博浪': 3,
#          '暮入': 3,
#          '淮陰': 7,
#          '張良': 3,
#          '未遇': 3,
#          '韓信': 6,
#          '劉項': 2,
#          '存亡': 3,
#          '兩臣': 2,
#          '暫到': 1,
#          '下邳': 4,
#          '受兵略': 2,
#          '來投': 3,
#          '漂母': 8,
#          '作主': 2,
#          '賢哲': 2,
#          '栖栖': 1,
#          '如此': 6,
#          '今時': 3,
#          '亦棄': 2,
#          '青雲': 44,
#          '有策': 2,
#          '不敢': 8,
#          '龍鱗': 3,
#          '竄身': 3,
#          '南國': 6,
#          '避胡': 3,
#          '寶書': 3,
#          '高閣': 3,
#          '金鞍': 8,
#          '駿馬': 11,
#          '故人': 31,
#          '昨日': 10,
#          '方爲': 2,
#          '宣城': 4,
#          '掣鈴': 2,
#          '交通': 2,
#          '二千': 8,
#          '有時': 8,
#          '六博': 4,
#          '壯心': 10,
#          '繞牀': 2,
#          '三帀': 1,
#          '一擲': 8,
#          '楚人': 5,
#          '每道': 2,
#          '張旭': 2,
#          '心藏': 2,
#          '風雲': 12,
#          '世莫': 2,
#          '三吳': 6,
#          '邦伯': 2,
#          '顧盼': 2,
#          '四海': 14,
#          '雄俠': 2,
#          '相推': 2,
#          '蕭曹': 5,
#          '曾作': 2,
#          '沛中': 2,
#          '攀龍': 9,
#          '附鳳': 2,
#          '當有': 3,
#          '溧陽': 2,
#          '酒樓': 3,
#          '三月': 12,
#          '楊花': 10,
#          '漠漠': 2,
#          '愁殺': 7,
#          '胡人': 3,
#          '吹玉': 10,
#          '吳歌': 9,
#          '白紵': 8,
#          '飛梁': 4,
#          '丈夫': 8,
#          '相見': 14,
#          '槌牛': 2,
#          '撾鼓': 2,
#          '衆賓': 4,
#          '我從': 2,
#          '此去': 7,
#          '得魚': 2,
#          '笑寄': 2,
#          '相親': 4,
#          '從軍': 4,
#          '逐虜': 3,
#          '金微': 2,
#          '笛奏': 4,
#          '梅花': 8,
#          '刀開': 2,
#          '鼓聲': 3,
#          '兵氣': 3,
#          '擁雲': 2,
#          '願斬': 2,
#          '長驅': 2,
#          '鐵關': 2,
#          '百戰': 7,
#          '沙場': 3,
#          '鐵衣': 2,
#          '城南': 3,
#          '已合': 2,
#          '數重': 2,
#          '突營': 2,
#          '射殺': 2,
#          '呼延將': 2,
#          '獨領': 2,
#          '殘兵': 2,
#          '千騎': 2,
#          '玉不': 2,
#          '自言': 10,
#          '魚目': 5,
#          '笑之': 2,
#          '卞和': 3,
#          '荆山': 7,
#          '長號': 4,
#          '泣血': 3,
#          '忠臣': 2,
#          '死爲': 2,
#          '刖足': 2,
#          '聽曲': 2,
#          '甯戚': 3,
#          '秦穆': 2,
#          '五羊': 2,
#          '買死': 2,
#          '百里': 11,
#          '洗拂': 2,
#          '當時': 18,
#          '如泥': 2,
#          '朝歌': 3,
#          '鼓刀': 3,
#          '虎變': 4,
#          '蟠溪': 1,
#          '一舉': 5,
#          '六合': 11,
#          '逐荒': 1,
#          '營丘': 2,
#          '平生': 11,
#          '渭水': 5,
#          '誰識': 3,
#          '此老': 2,
#          '奈何': 9,
#          '今之': 3,
#          '雙目': 4,
#          '征鴻': 2,
#          '北上': 6,
#          '何所': 12,
#          '太行': 10,
#          '磴道': 2,
#          '盤且': 2,
#          '巉巖': 4,
#          '穹蒼': 4,
#          '馬足': 3,
#          '側石': 2,
#          '車輪': 2,
#          '高岡': 2,
#          '沙塵': 7,
#          '朔方': 2,
#          '殺氣': 9,
#          '劒戟': 4,
#          '嚴風': 5,
#          '裂衣': 2,
#          '奔鯨': 4,
#          '鑿齒': 2,
#          '前行': 4,
#          '無歸': 5,
#          '返顧': 2,
#          '思舊': 3,
#          '慘戚': 2,
#          '冰雪': 2,
#          '悲號': 2,
#          '中腸': 2,
#          '尺布': 2,
#          '不掩': 2,
#          '皮膚': 2,
#          '枯桑': 7,
#          '汲水': 2,
#          '澗谷': 3,
#          '采薪': 2,
#          '隴坂': 2,
#          '掉尾': 2,
#          '磨牙': 4,
#          '飢飲': 2,
#          '零露': 2,
#          '歎此': 2,
#          '停驂': 2,
#          '胡風': 5,
#          '代馬': 3,
#          '北擁': 2,
#          '魯陽': 2,
#          '吳兵': 2,
#          '照海': 4,
#          '無顏': 2,
#          '老母': 2,
#          '與子': 2,
#          '呼天': 3,
#          '野草': 4,
#          '白馬': 21,
#          '悲鳴': 2,
#          '相追': 3,
#          '白楊': 10,
#          '秋月': 30,
#          '早落': 4,
#          '豫章': 4,
#          '本爲': 2,
#          '休明': 5,
#          '斬虜': 2,
#          '素不': 2,
#          '豈惜': 4,
#          '戰鬬': 2,
#          '爲君': 22,
#          '埽兇頑': 1,
#          '精感': 2,
#          '沒羽': 2,
#          '豈忘': 1,
#          '險艱': 3,
#          '樓船': 18,
#          '若鯨飛': 2,
#          '波蕩': 6,
#          '落星': 3,
#          '此曲': 7,
#          '鬢成': 2,
#          '朝騎': 2,
#          '五花': 2,
#          '謁帝': 5,
#          '秀色': 17,
#          '雲車': 4,
#          '珠箔': 4,
#          '金鞭': 5,
#          '遙指': 3,
#          '玉勒': 2,
#          '遲回': 3,
#          '夾轂': 2,
#          '借問': 27,
#          '疑從': 2,
#          '天上': 24,
#          '憐腸': 1,
#          '欲斷': 2,
#          '斜日': 2,
#          '相催': 7,
#          '下車': 1,
#          '輕盈': 1,
#          '飄然': 9,
#          '落梅': 4,
#          '邀入': 1,
#          '青綺': 3,
#          '當歌': 3,
#          '銜杯': 6,
#          '歌扇': 2,
#          '似月': 2,
#          '雲中': 6,
#          '不相': 16,
#          '不如': 20,
#          '已深': 2,
#          '未語': 2,
#          '可知': 2,
#          '胡爲': 6,
#          '空閨': 2,
#          '孤眠': 2,
#          '錦衾': 8,
#          '羅幃': 4,
#          '纏緜': 1,
#          '會有': 3,
#          '澹蕩': 4,
#          '更報': 2,
#          '長相': 16,
#          '光景': 7,
#          '不待': 5,
#          '須臾': 3,
#          '成絲': 4,
#          '行樂': 11,
#          '老去': 2,
#          '徒傷': 2,
#          '持此': 6,
#          '密意': 2,
#          '無令': 4,
#          '佳期': 7,
#          '相逢': 21,
#          '紅塵': 2,
#          '高揖': 5,
#          '萬戶': 8,
#          '君家': 7,
#          '阿那': 2,
#          '乘龍': 1,
#          '三天': 4,
#          '飛目': 1,
#          '兩角': 1,
#          '行至': 2,
#          '留田': 4,
#          '孤墳': 4,
#          '崢嶸': 11,
#          '積此': 2,
#          '春草': 10,
#          '悲風': 6,
#          '四邊': 5,
#          '埋沒': 3,
#          '蒿里': 2,
#          '古老': 2,
#          '向余': 3,
#          '言是': 2,
#          '蓬科': 2,
#          '馬鬣': 2,
#          '今已': 5,
#          '昔之': 2,
#          '弟死': 2,
#          '不葬': 2,
#          '他人': 9,
#          '於此': 11,
#          '銘旌': 2,
#          '桓山': 2,
#          '之禽': 2,
#          '別離': 11,
#          '欲去': 6,
#          '迴翔': 3,
#          '不能': 24,
#          '田氏': 2,
#          '倉卒': 3,
#          '骨肉': 3,
#          '青天': 49,
#          '紫荆': 2,
#          '交柯': 2,
#          '之木': 2,
#          '本同': 2,
#          '東枝': 3,
#          '西枝': 2,
#          '無心': 11,
#          '之物': 2,
#          '尚如': 4,
#          '參商': 2,
#          '胡乃': 3,
#          '天兵': 7,
#          '塞耳': 2,
#          '吳宮': 5,
#          '火起': 2,
#          '焚爾': 1,
#          '炎洲': 2,
#          '逐翠': 2,
#          '網羅': 2,
#          '門有': 2,
#          '車馬': 2,
#          '朱輪': 3,
#          '謂從': 2,
#          '丹霄': 3,
#          '乃是': 9,
#          '故鄉': 8,
#          '中堂': 2,
#          '坐客': 2,
#          '悲辛': 4,
#          '兩不': 4,
#          '停觴': 2,
#          '盈巾': 3,
#          '歎我': 2,
#          '飄颻': 13,
#          '空談': 2,
#          '霸王': 3,
#          '紫綬': 4,
#          '不挂': 2,
#          '雄劒': 3,
#          '玉匣': 4,
#          '陰符': 2,
#          '生素塵': 3,
#          '廓落': 3,
#          '流離': 3,
#          '湘水': 10,
#          '宗黨': 2,
#          '多爲': 4,
#          '泉下': 2,
#          '生苦': 2,
#          '死託': 2,
#          '萬鬼': 2,
#          '北風': 6,
#          '埋翳': 2,
#          '周與秦': 3,
#          '大運': 5,
#          '且如': 2,
#          '寧匪仁': 2,
#          '蠶叢': 3,
#          '及魚': 2,
#          '開國': 2,
#          '茫然': 11,
#          '爾來': 5,
#          '四萬': 4,
#          '八千': 4,
#          '乃與': 2,
#          '秦塞': 3,
#          '通人': 2,
#          '西當': 2,
#          '太白': 17,
#          '有鳥': 3,
#          '可以': 16,
#          '橫絕': 4,
#          '峨眉': 19,
#          '地崩': 2,
#          '山摧': 2,
#          '壯士': 31,
#          '黃鶴': 27,
#          '之飛': 1,
#          '尚不': 4,
#          '猨猱': 3,
#          '欲度': 2,
#          '攀緣': 1,
#          '青泥': 2,
#          '盤盤': 2,
#          '百步': 2,
#          '九折': 2,
#          '巖巒': 3,
#          '捫參': 2,
#          '歷井': 2,
#          '脅息': 2,
#          '以手': 2,
#          '撫膺': 2,
#          '長歎': 8,
#          '但見': 7,
#          '悲鳥': 2,
#          '枯木': 1,
#          '雄飛': 2,
#          '呼雌': 1,
#          '繞林': 2,
#          '又聞': 2,
#          ...})

# %%
result_li.most_common(10)
# Out:
# [('不可', 75),
#  ('黃金', 68),
#  ('春風', 65),
#  ('萬里', 60),
#  ('白日', 57),
#  ('明月', 52),
#  ('青天', 49),
#  ('相思', 49),
#  ('天地', 47),
#  ('青雲', 44)]

# %%
def tang_author_topK(author,K):
    author_seg = tang_df[tang_df['author']==author]['dic_total'].tolist()
    author_list = reduce(operator.add, author_seg) 
    result_author = Counter(author_list)
    return  result_author.most_common(K)

# %%
tang_author_topK('李白',10)
# Out:
# [('不可', 75),
#  ('黃金', 68),
#  ('春風', 65),
#  ('萬里', 60),
#  ('白日', 57),
#  ('明月', 52),
#  ('青天', 49),
#  ('相思', 49),
#  ('天地', 47),
#  ('青雲', 44)]

# %%
def song_author_topK(author,K):
    author_seg = song_df[song_df['author']==author]['dic_total'].tolist()
    author_list = reduce(operator.add, author_seg) 
    result_author = Counter(author_list)
    return  result_author.most_common(K)

# %%
song_author_topK('苏轼',10)
# Out:
# [('归去', 44),
#  ('何处', 39),
#  ('使君', 28),
#  ('佳人', 26),
#  ('人间', 23),
#  ('明月', 22),
#  ('江南', 20),
#  ('尊前', 20),
#  ('千里', 19),
#  ('风流', 18)]
